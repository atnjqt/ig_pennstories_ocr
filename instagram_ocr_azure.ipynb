# %% [markdown]
# # Microsoft Azure Computer Vision for Instagram image processing
# ## Etienne P Jacquot - ASC SYSADMIN - epj@asc.upenn.edu
#
# ### [Quickstart: Computer Vision client library for Python](https://docs.microsoft.com/en-us/azure/cognitive-services/computer-vision/quickstarts-sdk/python-sdk)
# __________________
#
# To [install Azure CLI](https://pypi.org/project/azure-cli/) for Python on MacOS:
# - `pip install azure-cli`
#
# To [install Azure SDKs](https://docs.microsoft.com/en-us/azure/cognitive-services/Custom-Vision-Service/python-tutorial):
# - `pip install azure.cognitiveservices.vision.computervision`
# - `pip install azure-cognitiveservices-vision-customvision`
#
#
# ### On Azure I created an `ASC-ComputerVision` endpoint w/ Free tier (20/minute, 5k per month)
#
# Save your credentials to `configs/config.ini` and do not share!
#
# #### *Update -->> latest version for computervision to avoid errors...*
#
# - more info https://pypi.org/project/azure-cognitiveservices-vision-computervision/
#
# `pip install azure-cognitiveservices-vision-computervision==0.7.0`
#
# _________

# %%
import pandas as pd
import os

import configparser
import sys
import time

import requests

from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials

# %% [markdown]
# ### Using PhantomBuster to get Instgram URLs for `@blackivystories`
#
# Save as csv in `./data/`
#
# - https://phantombuster.com/4737542404301822/phantoms/1973743622888750/console

# %%
df = pd.read_csv('./data/blackivystories_PostsExtractor_03012021.csv')

# %% [markdown]
# ## Reviewing columns, we can get our image URL as `imgUrl`

# %%
df.columns
# Out:
# Index(['postUrl', 'description', 'commentCount', 'likeCount', 'location',
#        'locationId', 'pubDate', 'likedByViewer', 'isSidecar', 'type',
#        'caption', 'profileUrl', 'username', 'sidePostUrl', 'imgUrl', 'postId',
#        'timestamp', 'query', 'taggedFullName1', 'taggedUsername1',
#        'taggedFullName2', 'taggedUsername2', 'taggedFullName3',
#        'taggedUsername3', 'fullName'],
#       dtype='object')

# %% [markdown]
# ## Download each image to `./img` for long term (OPTIONAL)
#
# - Microsoft Azure supports **remote_url** so you *can* do ocr without saving the images... I think that the `imgUrl` is an *s3content* served by facebook/instagram and really it is not supposed to be a permalink. Downloading is for long term reference.

# %%
mkdir ./img
# Out:
# mkdir: ./img: File exists

# %% [markdown]
# ## Function to download & save as `postId`.png

# %%
def img_download(x):
    f = open('./img/{}.png'.format(str(x.postId)),'wb') # <-- Instagram postID as filename
    f.write(requests.get(x.imgUrl).content)             # <-- requests module get imgUrl (time sensitive content)
    f.close()
    return

# %%
df.apply(lambda x: img_download(x), axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 623    None
# 624    None
# 625    None
# 626    None
# 627    None
# Length: 628, dtype: object

# %% [markdown]
# ## Now run Microsoft Azure OCR to extract stories from downloaded instagram posts

# %%
ig_pngs = [item for item in os.listdir('./img/') if item.endswith('.png')]

# %% [markdown]
# ### Set your Azure access key & endpoint
#
# - this is your `./configs/config.ini`, specifically the **ASC-COMPUTERVISION** profile

# %%
# add azure Computer Vision key and endpoint to config.ini
azure_cred = {}
config = configparser.ConfigParser()

config.read('./configs/config.ini') # <--- add your Twitter API tokens to this file!
for item,value in config['ASC-COMPUTERVISION'].items():
    azure_cred[item]=value

# %%
# Azure Variables Here!
_url = azure_cred['endpoint'] # Here, paste your full endpoint from the Azure portal
_key = azure_cred['key1']  # Here, paste your primary key
_maxNumRetries = 10

# %% [markdown]
# ## Using the Azure ComputerVision API Client

# %%
computervision_client = ComputerVisionClient(_url, CognitiveServicesCredentials(_key))

# %% [markdown]
# ### Get a Computer Vision quick description - remote url
#
# - we know it's likely text content for this instagram page.

# %%
# sample url for example... 
remote_image_url = df.imgUrl.iloc[-4]

# %%
'''
Describe an image - remote
This example describes the contents of an image with the confidence score.
'''
print("===== Describe an image - remote =====")
# Call API
description_results = computervision_client.describe_image(remote_image_url)

# Get the captions (descriptions) from the response, with confidence level
print("Description of remote image: ")
if (len(description_results.captions) == 0):
    print("No description detected.")
else:
    for caption in description_results.captions:
        print("'{}' with confidence {:.2f}%".format(caption.text, caption.confidence * 100))
# Out:
# ===== Describe an image - remote =====
# Description of remote image:
# 'text' with confidence 98.24%

# %% [markdown]
# ## Here is the sample remote url image:
#
# ![](./img/2347618041418001201.png)

# %% [markdown]
# __________
#
# ## Recognize Printed Text with OCR - remote URL example
#
# Helpful list of examples here https://github.com/Azure-Samples/cognitive-services-quickstart-code/blob/master/python/ComputerVision/ComputerVisionQuickstart.py, though the text is not handwritten...

# %%
'''
Recognize Printed Text with OCR - local
This example will extract, using OCR, printed text in an image, then print results line by line.
'''
print("===== Detect Printed Text with OCR - local =====")

#remote_printed_text_image_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/printed_text.jpg"
#remote_printed_text_image_url=remote_image_url
local_image_printed_text_path = "./img/{}".format(ig_pngs[-1])
local_image_printed_text = open(local_image_printed_text_path, "rb")

ocr_result_local = computervision_client.recognize_printed_text_in_stream(local_image_printed_text)
for region in ocr_result_local.regions:
    for line in region.lines:
        print("Bounding box: {}".format(line.bounding_box))
        s = ""
        for word in line.words:
            s += word.text + " "
        print(s)
print()
'''
END - Recognize Printed Text with OCR - local
'''
# Out:
# ===== Detect Printed Text with OCR - local =====
# Bounding box: 89,118,906,56
# Last semester I took one of the many
# Bounding box: 106,185,868,56
# race/gender/class-based discussion
# Bounding box: 74,251,932,44
# courses at Cornell. The first half of the
# Bounding box: 160,318,758,44
# class had a South Asian interim
# Bounding box: 145,384,793,59
# professor. During one of the first
# Bounding box: 83,450,917,60
# classes, we discussed a piece of work
# Bounding box: 145,517,785,57
# from an Enlightenment thinker. I
# Bounding box: 198,583,686,60
# brought up the fact that this
# Bounding box: 84,650,915,57
# Enlightenment thinker was integral to
# Bounding box: 195,717,687,44
# the construction of race and
# Bounding box: 100,783,884,59
# post-enlightenment justifications for
# Bounding box: 90,850,902,56
# slavery, and thus we should consider
# Bounding box: 137,917,801,58
# the piece through that context...
# Bounding box: 659,992,353,39
# @blackivystories
# '\nEND - Recognize Printed Text with OCR - local\n'

# %% [markdown]
# ## This is that image:
#
# ![](./img/2359986520683068201.png)

# %% [markdown]
# _______
#
# ## Looking at our Example OCR content in a DataFrame

# %%
ocr_df = pd.DataFrame.from_dict(ocr_result_local.as_dict())

# %%
ocr_df
# Out:
#   language  text_angle orientation  \
# 0       en         0.0          Up
#
#                                              regions
# 0  {'bounding_box': '74,118,938,913', 'lines': [{...

# %%
ocr_df.regions[0].keys()
# Out:
# dict_keys(['bounding_box', 'lines'])

# %% [markdown]
# ### We can see all the words w/ bounding box information

# %%
ocr_text = []

for line in ocr_df.regions[0]['lines']:
    for word in line['words']:
        #print(word['text'])
        ocr_text.append(word['text'])
        
print(ocr_text)
# Out:
# ['Last', 'semester', 'I', 'took', 'one', 'of', 'the', 'many', 'race/gender/class-based', 'discussion', 'courses', 'at', 'Cornell.', 'The', 'first', 'half', 'of', 'the', 'class', 'had', 'a', 'South', 'Asian', 'interim', 'professor.', 'During', 'one', 'of', 'the', 'first', 'classes,', 'we', 'discussed', 'a', 'piece', 'of', 'work', 'from', 'an', 'Enlightenment', 'thinker.', 'I', 'brought', 'up', 'the', 'fact', 'that', 'this', 'Enlightenment', 'thinker', 'was', 'integral', 'to', 'the', 'construction', 'of', 'race', 'and', 'post-enlightenment', 'justifications', 'for', 'slavery,', 'and', 'thus', 'we', 'should', 'consider', 'the', 'piece', 'through', 'that', 'context...', '@blackivystories']

# %% [markdown]
# _________
#
# # RUNNING FOR ALL IMAGES W/ RATE LIMITING
#
# Make sure to start with **AT LEAST** 60 seconds lead in time to prevent rate limits... this is a simple looping, I am guessing the computervision_client has a `rate_limiting_wait=yes` or something like that ...

# %%
dfs = []

i = 0

for url in ig_pngs:
    
    print('getting ocr for -->',url)
    
    # RATE LIMITING, CHECK IN BEGINNING OF THE LOOP
    if i == 20:
        print('i --> {}'.format(i))
        print('waiting for 63 seconds...')
        i=0
        time.sleep(63)
        
    else:
        # TRY TO READ LOCAL IMAGE FILE
        try:
            local_image_printed_text_path = "./img/{}".format(url)
            local_image_printed_text = open(local_image_printed_text_path, "rb")
        except:
            print('oops! failed to open image...')
            sys.stderr.write()
            break
        # TRY TO GET AZURE OCR TEXT EXTRACTION
        try:
            ocr_result_local = computervision_client.recognize_printed_text_in_stream(local_image_printed_text)
            ocr_df = pd.DataFrame.from_dict(ocr_result_local.as_dict())
            #ocr_df['img_filename'] = url
            ocr_df['postId'] = url.strip('.png')
            dfs.append(ocr_df)
            i = i + 1
        except:
            print('oops! failed to get azure ocr...')
            sys.stderr.write()
            break
# Out:
# getting ocr for --> 2350613102216966045.png
# getting ocr for --> 2340140894484999761.png
# getting ocr for --> 2347618041418001201.png
# getting ocr for --> 2393806188103257343.png
# getting ocr for --> 2343348859268581716.png
# getting ocr for --> 2338912215348179434.png
# getting ocr for --> 2354215615625321577.png
# getting ocr for --> 2362123660724497627.png
# getting ocr for --> 2360747577210992175.png
# getting ocr for --> 2382930617014024873.png
# getting ocr for --> 2367252283412384155.png
# getting ocr for --> 2374422979850657699.png
# getting ocr for --> 2349874525984086923.png
# getting ocr for --> 2363612331470268025.png
# getting ocr for --> 2362839721379746585.png
# getting ocr for --> 2430069395260057077.png
# getting ocr for --> 2340997810832781473.png
# getting ocr for --> 2345503318656671388.png
# getting ocr for --> 2358282383087974949.png
# getting ocr for --> 2343319077327950041.png
# getting ocr for --> 2344794897858880330.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2344590726186435769.png
# getting ocr for --> 2343993744749285462.png
# getting ocr for --> 2375109852688305770.png
# getting ocr for --> 2365509693604156598.png
# getting ocr for --> 2341641328651537664.png
# getting ocr for --> 2358463475283778085.png
# getting ocr for --> 2353425698536240582.png
# getting ocr for --> 2344058177420958423.png
# getting ocr for --> 2343259965743429711.png
# getting ocr for --> 2338000555708175647.png
# getting ocr for --> 2348213874991747260.png
# getting ocr for --> 2364333498263052433.png
# getting ocr for --> 2341764308463485199.png
# getting ocr for --> 2335111117062063771.png
# getting ocr for --> 2359269429529181284.png
# getting ocr for --> 2354066180979200856.png
# getting ocr for --> 2359829138476824911.png
# getting ocr for --> 2370827720692563803.png
# getting ocr for --> 2358463475266980051.png
# getting ocr for --> 2361479988026720146.png
# getting ocr for --> 2337942433006333282.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2383680821930041843.png
# getting ocr for --> 2342541965549375735.png
# getting ocr for --> 2363612331478776801.png
# getting ocr for --> 2350389633843779628.png
# getting ocr for --> 2368475373387567859.png
# getting ocr for --> 2348957452671918633.png
# getting ocr for --> 2341641328634807062.png
# getting ocr for --> 2351360786657865537.png
# getting ocr for --> 2352622431757466988.png
# getting ocr for --> 2366312495469464448.png
# getting ocr for --> 2365650660521011802.png
# getting ocr for --> 2355640402197289448.png
# getting ocr for --> 2340324150161669705.png
# getting ocr for --> 2393808657642408107.png
# getting ocr for --> 2348136635675481506.png
# getting ocr for --> 2376389501200570722.png
# getting ocr for --> 2380098885147659048.png
# getting ocr for --> 2349058122955646991.png
# getting ocr for --> 2364905951024552921.png
# getting ocr for --> 2423441911672388451.png
# getting ocr for --> 2343856422900760653.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2380882158391992819.png
# getting ocr for --> 2361420716295203208.png
# getting ocr for --> 2351890701736075824.png
# getting ocr for --> 2340140894501910642.png
# getting ocr for --> 2370827720675703879.png
# getting ocr for --> 2370106296235291074.png
# getting ocr for --> 2351841377593466653.png
# getting ocr for --> 2393810755968749852.png
# getting ocr for --> 2344655490593972225.png
# getting ocr for --> 2362176714291150300.png
# getting ocr for --> 2368445510723283912.png
# getting ocr for --> 2394694706073628452.png
# getting ocr for --> 2349092038559211207.png
# getting ocr for --> 2375200258251882578.png
# getting ocr for --> 2374505348372757122.png
# getting ocr for --> 2361902527395693892.png
# getting ocr for --> 2349743182671476455.png
# getting ocr for --> 2361479988026732584.png
# getting ocr for --> 2349874525958978000.png
# getting ocr for --> 2348213875033526199.png
# getting ocr for --> 2370120197274428960.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2364068340991222519.png
# getting ocr for --> 2338852670651334930.png
# getting ocr for --> 2346670157025657598.png
# getting ocr for --> 2339367505252091222.png
# getting ocr for --> 2352622431774188773.png
# getting ocr for --> 2374482858690769432.png
# getting ocr for --> 2342578400335833284.png
# getting ocr for --> 2375109852705177910.png
# getting ocr for --> 2348213875016836237.png
# getting ocr for --> 2370158408399016470.png
# getting ocr for --> 2428865527016687951.png
# getting ocr for --> 2343348859285360235.png
# getting ocr for --> 2351276205162108427.png
# getting ocr for --> 2341840678684123048.png
# getting ocr for --> 2378679092716667731.png
# getting ocr for --> 2348213875025253079.png
# getting ocr for --> 2361902527412577679.png
# getting ocr for --> 2422785836073815824.png
# getting ocr for --> 2431454867161038669.png
# getting ocr for --> 2362196667702565635.png
# getting ocr for --> 2364824530943677243.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2359269429520733404.png
# getting ocr for --> 2372049268329754833.png
# getting ocr for --> 2367998458054578450.png
# getting ocr for --> 2339560353989789904.png
# getting ocr for --> 2347395383501814583.png
# getting ocr for --> 2332164025536572487.png
# getting ocr for --> 2357773803578639812.png
# getting ocr for --> 2349743182813914031.png
# getting ocr for --> 2375712551037439604.png
# getting ocr for --> 2374212574301737027.png
# getting ocr for --> 2346881557639554017.png
# getting ocr for --> 2348357136997948675.png
# getting ocr for --> 2381743876538297550.png
# getting ocr for --> 2379583926949094123.png
# getting ocr for --> 2341811246254661308.png
# getting ocr for --> 2365033301888365361.png
# getting ocr for --> 2353281307725210042.png
# getting ocr for --> 2364333498271320746.png
# getting ocr for --> 2337942432972613555.png
# getting ocr for --> 2339486576794704510.png
# getting ocr for --> 2387419119109970711.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2346923971028837962.png
# getting ocr for --> 2350462307710312945.png
# getting ocr for --> 2354135157659018166.png
# getting ocr for --> 2338703203205839962.png
# getting ocr for --> 2365805455579938917.png
# getting ocr for --> 2350297533328584623.png
# getting ocr for --> 2340274376262271283.png
# getting ocr for --> 2348414774049808500.png
# getting ocr for --> 2339486576820008000.png
# getting ocr for --> 2430069395268473539.png
# getting ocr for --> 2348136635692346480.png
# getting ocr for --> 2366446066117001768.png
# getting ocr for --> 2375143600838410458.png
# getting ocr for --> 2351078056535642447.png
# getting ocr for --> 2353936860159863141.png
# getting ocr for --> 2351946715122630387.png
# getting ocr for --> 2371509661070601548.png
# getting ocr for --> 2341672619761550103.png
# getting ocr for --> 2350613102200226814.png
# getting ocr for --> 2356989395061759585.png
# getting ocr for --> 2348296081789806606.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2348136635700629234.png
# getting ocr for --> 2356314234281252303.png
# getting ocr for --> 2374464196688877923.png
# getting ocr for --> 2362001090620573481.png
# getting ocr for --> 2377371228299552606.png
# getting ocr for --> 2422785836031753611.png
# getting ocr for --> 2362839721396623535.png
# getting ocr for --> 2346169071789586779.png
# getting ocr for --> 2369448237754464758.png
# getting ocr for --> 2367793521660212637.png
# getting ocr for --> 2385732386198843940.png
# getting ocr for --> 2376633140937978562.png
# getting ocr for --> 2354811383885162159.png
# getting ocr for --> 2371339433657387672.png
# getting ocr for --> 2348136635667247146.png
# getting ocr for --> 2362196667710900527.png
# getting ocr for --> 2369448237762686552.png
# getting ocr for --> 2423779835479806297.png
# getting ocr for --> 2419871909824200319.png
# getting ocr for --> 2344077124325111120.png
# getting ocr for --> 2342596369514265263.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2341874691075260207.png
# getting ocr for --> 2340324150178289263.png
# getting ocr for --> 2352015248439320762.png
# getting ocr for --> 2368522112152786043.png
# getting ocr for --> 2337942432997824418.png
# getting ocr for --> 2368435367914582293.png
# getting ocr for --> 2372162821670039666.png
# getting ocr for --> 2351360786674632041.png
# getting ocr for --> 2360747577135337367.png
# getting ocr for --> 2336023598091096420.png
# getting ocr for --> 2340831217473527773.png
# getting ocr for --> 2364824530960286687.png
# getting ocr for --> 2368414402602164737.png
# getting ocr for --> 2348357136972929549.png
# getting ocr for --> 2340413922787868078.png
# getting ocr for --> 2435456592645585531.png
# getting ocr for --> 2338953169153075283.png
# getting ocr for --> 2425268245767683320.png
# getting ocr for --> 2339615509221709310.png
# getting ocr for --> 2429280809241780408.png
# getting ocr for --> 2375084936458939021.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2346670157042540479.png
# getting ocr for --> 2356258355028499940.png
# getting ocr for --> 2430069395276709367.png
# getting ocr for --> 2344748250403628742.png
# getting ocr for --> 2342565041326525472.png
# getting ocr for --> 2374505348406373809.png
# getting ocr for --> 2342422486387566181.png
# getting ocr for --> 2362809286335605783.png
# getting ocr for --> 2376389501183794364.png
# getting ocr for --> 2394697772453660948.png
# getting ocr for --> 2336715794297532565.png
# getting ocr for --> 2368671305106211205.png
# getting ocr for --> 2333791347658297331.png
# getting ocr for --> 2348136635709171811.png
# getting ocr for --> 2339486576786447800.png
# getting ocr for --> 2377111197339475183.png
# getting ocr for --> 2361444900643638721.png
# getting ocr for --> 2362839721413271524.png
# getting ocr for --> 2368556934749432924.png
# getting ocr for --> 2343856422926016598.png
# getting ocr for --> 2370043346317290101.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2338222891854142886.png
# getting ocr for --> 2334393591630112802.png
# getting ocr for --> 2351841377584946561.png
# getting ocr for --> 2348876611606422484.png
# getting ocr for --> 2366312495494650181.png
# getting ocr for --> 2357090857364396524.png
# getting ocr for --> 2379480805069319749.png
# getting ocr for --> 2352015248422411166.png
# getting ocr for --> 2356258355112399066.png
# getting ocr for --> 2368016749515204816.png
# getting ocr for --> 2349788573789884120.png
# getting ocr for --> 2335111117053777352.png
# getting ocr for --> 2365767204567634501.png
# getting ocr for --> 2343213371790582543.png
# getting ocr for --> 2369962037578467862.png
# getting ocr for --> 2352015248430732310.png
# getting ocr for --> 2374482858707644548.png
# getting ocr for --> 2351841377618518412.png
# getting ocr for --> 2347395383493609677.png
# getting ocr for --> 2362809286352377942.png
# getting ocr for --> 2341672619778409606.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2370857024625078605.png
# getting ocr for --> 2377255424044295384.png
# getting ocr for --> 2349874525992549603.png
# getting ocr for --> 2353425698519369974.png
# getting ocr for --> 2349823662741735416.png
# getting ocr for --> 2429280809250142900.png
# getting ocr for --> 2419871909807463066.png
# getting ocr for --> 2346169071806241840.png
# getting ocr for --> 2376633140921041056.png
# getting ocr for --> 2423676819581787073.png
# getting ocr for --> 2387427293204336829.png
# getting ocr for --> 2368646388541347964.png
# getting ocr for --> 2338983808585733532.png
# getting ocr for --> 2377315409721604209.png
# getting ocr for --> 2360726727283772005.png
# getting ocr for --> 2332906677534069635.png
# getting ocr for --> 2345414835728429967.png
# getting ocr for --> 2423676819573441657.png
# getting ocr for --> 2341672619778442969.png
# getting ocr for --> 2337324546058998799.png
# getting ocr for --> 2349788573798268230.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2338133832704059789.png
# getting ocr for --> 2349672464692655438.png
# getting ocr for --> 2387436188585146047.png
# getting ocr for --> 2351776914773204149.png
# getting ocr for --> 2357633400074369489.png
# getting ocr for --> 2367208342071562287.png
# getting ocr for --> 2365846953403056519.png
# getting ocr for --> 2343779167872945104.png
# getting ocr for --> 2372049268346714352.png
# getting ocr for --> 2364305340541289267.png
# getting ocr for --> 2332224388852583995.png
# getting ocr for --> 2342399703758793395.png
# getting ocr for --> 2368522112135888568.png
# getting ocr for --> 2353425698511077487.png
# getting ocr for --> 2358364364719215074.png
# getting ocr for --> 2424226334743318008.png
# getting ocr for --> 2368389542626797012.png
# getting ocr for --> 2337324546042146863.png
# getting ocr for --> 2370857024641835254.png
# getting ocr for --> 2335111117078869465.png
# getting ocr for --> 2339432879242873031.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2369868362940916707.png
# getting ocr for --> 2354905971773826143.png
# getting ocr for --> 2360017524659430988.png
# getting ocr for --> 2346169071814786652.png
# getting ocr for --> 2338953169170043576.png
# getting ocr for --> 2337885026070617143.png
# getting ocr for --> 2346820447217438000.png
# getting ocr for --> 2354215615608433514.png
# getting ocr for --> 2367998458063053414.png
# getting ocr for --> 2351991123658340910.png
# getting ocr for --> 2383680821938589042.png
# getting ocr for --> 2367888682465539083.png
# getting ocr for --> 2348414774041564773.png
# getting ocr for --> 2354215615633741252.png
# getting ocr for --> 2342565041309910663.png
# getting ocr for --> 2344794897867314630.png
# getting ocr for --> 2351890701736119757.png
# getting ocr for --> 2364236186148897017.png
# getting ocr for --> 2353281307716872242.png
# getting ocr for --> 2368421482293832127.png
# getting ocr for --> 2366531196194052913.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2336534255198693202.png
# getting ocr for --> 2366312495460948896.png
# getting ocr for --> 2383623127659088604.png
# getting ocr for --> 2348136635658798555.png
# getting ocr for --> 2385320759435693125.png
# getting ocr for --> 2364305340524438204.png
# getting ocr for --> 2341715256371713728.png
# getting ocr for --> 2379538492729662205.png
# getting ocr for --> 2344058177445967292.png
# getting ocr for --> 2376523636208526208.png
# getting ocr for --> 2379429021537840997.png
# getting ocr for --> 2380788950655847458.png
# getting ocr for --> 2375200258268630696.png
# getting ocr for --> 2347576850165049994.png
# getting ocr for --> 2360595234209163018.png
# getting ocr for --> 2341095554339524470.png
# getting ocr for --> 2387436188601922989.png
# getting ocr for --> 2355578853445112830.png
# getting ocr for --> 2366410401144770845.png
# getting ocr for --> 2337942432989449945.png
# getting ocr for --> 2387432933360439247.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2344503727287068032.png
# getting ocr for --> 2378679092724961143.png
# getting ocr for --> 2349874526009420422.png
# getting ocr for --> 2338912215364823919.png
# getting ocr for --> 2368453921720257616.png
# getting ocr for --> 2353197148537218577.png
# getting ocr for --> 2355515227883508545.png
# getting ocr for --> 2343259965751667708.png
# getting ocr for --> 2387387213458829760.png
# getting ocr for --> 2349858331264665686.png
# getting ocr for --> 2364171030882526640.png
# getting ocr for --> 2435456592628756077.png
# getting ocr for --> 2342541965541101685.png
# getting ocr for --> 2393810755985534080.png
# getting ocr for --> 2354811383902035944.png
# getting ocr for --> 2353988936663408928.png
# getting ocr for --> 2368389542651903891.png
# getting ocr for --> 2367793521676994963.png
# getting ocr for --> 2361381864339671003.png
# getting ocr for --> 2365819946883443412.png
# getting ocr for --> 2333023030429563591.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2337245180423726337.png
# getting ocr for --> 2362176714307939407.png
# getting ocr for --> 2433745246199538105.png
# getting ocr for --> 2344768231178698672.png
# getting ocr for --> 2355640402188819221.png
# getting ocr for --> 2356829473976131159.png
# getting ocr for --> 2359224950042398446.png
# getting ocr for --> 2361902527378929989.png
# getting ocr for --> 2370069315149207367.png
# getting ocr for --> 2354135157675909257.png
# getting ocr for --> 2387432933368853632.png
# getting ocr for --> 2369868362924082836.png
# getting ocr for --> 2362885035541271431.png
# getting ocr for --> 2431454867144135206.png
# getting ocr for --> 2367888682457038673.png
# getting ocr for --> 2368460744393316041.png
# getting ocr for --> 2345503318665021204.png
# getting ocr for --> 2424520003308305977.png
# getting ocr for --> 2394697772470556429.png
# getting ocr for --> 2361444900652037458.png
# getting ocr for --> 2371509661062342377.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2360747577152305414.png
# getting ocr for --> 2394694706048502930.png
# getting ocr for --> 2358282383096488884.png
# getting ocr for --> 2346743023452737565.png
# getting ocr for --> 2349788573781468272.png
# getting ocr for --> 2426388442528407629.png
# getting ocr for --> 2343925246304020576.png
# getting ocr for --> 2420053014594567050.png
# getting ocr for --> 2423441911664047448.png
# getting ocr for --> 2360684539606901219.png
# getting ocr for --> 2370069315166040074.png
# getting ocr for --> 2365767204575967760.png
# getting ocr for --> 2345328829427798359.png
# getting ocr for --> 2340997810815764888.png
# getting ocr for --> 2359986520691407453.png
# getting ocr for --> 2364171030899412613.png
# getting ocr for --> 2425268245776156547.png
# getting ocr for --> 2368383356431018757.png
# getting ocr for --> 2368429690009707323.png
# getting ocr for --> 2353355415943041815.png
# getting ocr for --> 2369142546795753618.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2351890701719257708.png
# getting ocr for --> 2354232088192103903.png
# getting ocr for --> 2362196667685835822.png
# getting ocr for --> 2377878835980265236.png
# getting ocr for --> 2363487714739088501.png
# getting ocr for --> 2433745246216486181.png
# getting ocr for --> 2356365673233746208.png
# getting ocr for --> 2376598787465717163.png
# getting ocr for --> 2367123277149077856.png
# getting ocr for --> 2339486576828318344.png
# getting ocr for --> 2379480805086099956.png
# getting ocr for --> 2344058177429276045.png
# getting ocr for --> 2351167870291367797.png
# getting ocr for --> 2379288361677688308.png
# getting ocr for --> 2350598473231172446.png
# getting ocr for --> 2365767204592748725.png
# getting ocr for --> 2358282383004194469.png
# getting ocr for --> 2347618041401235984.png
# getting ocr for --> 2344728746428486287.png
# getting ocr for --> 2380882158408921069.png
# getting ocr for --> 2347528872746474552.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2365033301871567777.png
# getting ocr for --> 2372302268319359340.png
# getting ocr for --> 2424520003291701427.png
# getting ocr for --> 2335919366515996636.png
# getting ocr for --> 2343069988057024551.png
# getting ocr for --> 2347651152772273969.png
# getting ocr for --> 2357134370349111165.png
# getting ocr for --> 2353281307700019230.png
# getting ocr for --> 2359224950025784391.png
# getting ocr for --> 2377111197347945911.png
# getting ocr for --> 2359079319059720022.png
# getting ocr for --> 2370069315132579726.png
# getting ocr for --> 2344728746420260379.png
# getting ocr for --> 2352015248405648689.png
# getting ocr for --> 2422785836048583467.png
# getting ocr for --> 2368606957461770983.png
# getting ocr for --> 2341116129632012635.png
# getting ocr for --> 2363363966698570654.png
# getting ocr for --> 2342541965524285298.png
# getting ocr for --> 2344036185670041112.png
# getting ocr for --> 2343213371815880634.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2379583926957375195.png
# getting ocr for --> 2361479988018189333.png
# getting ocr for --> 2336534255181816164.png
# getting ocr for --> 2375793102998026740.png
# getting ocr for --> 2375933116155278063.png
# getting ocr for --> 2404947036538922855.png
# getting ocr for --> 2346923971003551508.png
# getting ocr for --> 2366312495486221352.png
# getting ocr for --> 2347528872754918165.png
# getting ocr for --> 2365650660537718139.png
# getting ocr for --> 2369329806791083157.png
# getting ocr for --> 2349874525975692618.png
# getting ocr for --> 2366971400604266859.png
# getting ocr for --> 2355515227908825802.png
# getting ocr for --> 2343123965964551318.png
# getting ocr for --> 2367208342080134823.png
# getting ocr for --> 2372085074314565133.png
# getting ocr for --> 2335111117095606127.png
# getting ocr for --> 2361479988001610561.png
# getting ocr for --> 2360720290386065136.png
# getting ocr for --> 2336023598107765663.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2350297533303418931.png
# getting ocr for --> 2351841377576643880.png
# getting ocr for --> 2354751437608986432.png
# getting ocr for --> 2356365673217055087.png
# getting ocr for --> 2366410401153049210.png
# getting ocr for --> 2335111117154412138.png
# getting ocr for --> 2378641223671152848.png
# getting ocr for --> 2346972879054670675.png
# getting ocr for --> 2370721492872149981.png
# getting ocr for --> 2351776914756570863.png
# getting ocr for --> 2368435367931341898.png
# getting ocr for --> 2377255424069382597.png
# getting ocr for --> 2350297533337006144.png
# getting ocr for --> 2368389542660287343.png
# getting ocr for --> 2429280809216615779.png
# getting ocr for --> 2374347343379539118.png
# getting ocr for --> 2336817725867132042.png
# getting ocr for --> 2380901976906222205.png
# getting ocr for --> 2372835206844880089.png
# getting ocr for --> 2357114200159216587.png
# getting ocr for --> 2333662143650401152.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2368016749531963027.png
# getting ocr for --> 2352652055807865413.png
# getting ocr for --> 2340901971799893100.png
# getting ocr for --> 2377985380814577457.png
# getting ocr for --> 2349672464675904928.png
# getting ocr for --> 2373683175634517169.png
# getting ocr for --> 2351360786682992437.png
# getting ocr for --> 2352517526443208837.png
# getting ocr for --> 2368475373421199243.png
# getting ocr for --> 2339367505243773228.png
# getting ocr for --> 2384302964191182389.png
# getting ocr for --> 2362628399081798743.png
# getting ocr for --> 2374464196705608790.png
# getting ocr for --> 2387390806937199879.png
# getting ocr for --> 2346923971020551672.png
# getting ocr for --> 2351841377610150165.png
# getting ocr for --> 2368407990249575658.png
# getting ocr for --> 2362001090628976249.png
# getting ocr for --> 2335111117087351564.png
# getting ocr for --> 2334393591613187761.png
# getting ocr for --> 2348876611623238495.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2374505348389409660.png
# getting ocr for --> 2367964724064529300.png
# getting ocr for --> 2370617830665462762.png
# getting ocr for --> 2332142997762728939.png
# getting ocr for --> 2344655490577271795.png
# getting ocr for --> 2337518380239907782.png
# getting ocr for --> 2341129156066533837.png
# getting ocr for --> 2336023598082636006.png
# getting ocr for --> 2351276205145343654.png
# getting ocr for --> 2350598473231236542.png
# getting ocr for --> 2354135157667360872.png
# getting ocr for --> 2349823662758363804.png
# getting ocr for --> 2356314234264236851.png
# getting ocr for --> 2380026237512308163.png
# getting ocr for --> 2340390698783909517.png
# getting ocr for --> 2345230249845083298.png
# getting ocr for --> 2354672320117003257.png
# getting ocr for --> 2343823665403347980.png
# getting ocr for --> 2362839721404805164.png
# getting ocr for --> 2357051281623030419.png
# getting ocr for --> 2350462307693656025.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2350567111011019477.png
# getting ocr for --> 2342318364292383897.png
# getting ocr for --> 2337942432939219602.png
# getting ocr for --> 2426535005074640138.png
# getting ocr for --> 2430852767196546843.png
# getting ocr for --> 2335111117120804287.png
# getting ocr for --> 2384302964207881545.png
# getting ocr for --> 2339367505294234939.png
# getting ocr for --> 2376598787448926159.png
# getting ocr for --> 2372878604712548456.png
# getting ocr for --> 2362176714282746976.png
# getting ocr for --> 2374392045575328512.png
# getting ocr for --> 2338133832678807462.png
# getting ocr for --> 2341715256355014515.png
# getting ocr for --> 2375793103056717890.png
# getting ocr for --> 2335111117112448272.png
# getting ocr for --> 2374505348397921515.png
# getting ocr for --> 2378641223654546051.png
# getting ocr for --> 2354672320167413438.png
# getting ocr for --> 2375190511159303074.png
# getting ocr for --> 2367056002173656087.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2355431708108945912.png
# getting ocr for --> 2362885035524396596.png
# getting ocr for --> 2349578053073824475.png
# getting ocr for --> 2337324546075822545.png
# getting ocr for --> 2341147065887131780.png
# getting ocr for --> 2341874691092048335.png
# getting ocr for --> 2357552012046283652.png
# getting ocr for --> 2355431708125745577.png
# getting ocr for --> 2352622431765980023.png
# getting ocr for --> 2365674309122746377.png
# getting ocr for --> 2334582496564180811.png
# getting ocr for --> 2427317152358073335.png
# getting ocr for --> 2365819946866638091.png
# getting ocr for --> 2371367760283737428.png
# getting ocr for --> 2379538492713035318.png
# getting ocr for --> 2371509661045464400.png
# getting ocr for --> 2354232088175448292.png
# getting ocr for --> 2340191644722972950.png
# getting ocr for --> 2423583352931245686.png
# getting ocr for --> 2380788950681010364.png
# getting ocr for --> 2342349126534264002.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2368475373404172667.png
# getting ocr for --> 2380098885164288697.png
# getting ocr for --> 2341672619744721693.png
# getting ocr for --> 2375084936442323426.png
# getting ocr for --> 2335111117103967439.png
# getting ocr for --> 2368488071005282197.png
# getting ocr for --> 2332161255416871592.png
# getting ocr for --> 2353988936671920290.png
# getting ocr for --> 2345414835720035476.png
# getting ocr for --> 2338079904054525231.png
# getting ocr for --> 2404947036555467877.png
# getting ocr for --> 2424520003274680212.png
# getting ocr for --> 2375712551020586988.png
# getting ocr for --> 2345328829436105470.png
# getting ocr for --> 2361381864323038420.png
# getting ocr for --> 2368398231001739924.png
# getting ocr for --> 2381743876513122921.png
# getting ocr for --> 2343014340783006569.png
# getting ocr for --> 2338755367102040354.png
# getting ocr for --> 2368466666985439838.png
# getting ocr for --> 2350598473205942259.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2342349126525948693.png
# getting ocr for --> 2348432869283874448.png
# getting ocr for --> 2379429021554748584.png
# getting ocr for --> 2346951545213773637.png
# getting ocr for --> 2374287166861143321.png
# getting ocr for --> 2350598473248006810.png
# getting ocr for --> 2348296081798314748.png
# getting ocr for --> 2359978722196918328.png
# getting ocr for --> 2335111117145941491.png
# getting ocr for --> 2422785836057044369.png
# getting ocr for --> 2340424517121701190.png
# getting ocr for --> 2362058314843744418.png
# getting ocr for --> 2349030837548720572.png
# getting ocr for --> 2376633140929422010.png
# getting ocr for --> 2333202311323551922.png
# getting ocr for --> 2377878835963512519.png
# getting ocr for --> 2343856422917707590.png
# getting ocr for --> 2345230249861976936.png
# getting ocr for --> 2332906677525548127.png
# getting ocr for --> 2338852670634600918.png
# getting ocr for --> 2343856422942927509.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2365846953419760656.png
# getting ocr for --> 2348357136998183723.png
# getting ocr for --> 2332251841385804740.png
# getting ocr for --> 2360747577160610239.png
# getting ocr for --> 2367714801175808544.png
# getting ocr for --> 2433060230104727519.png
# getting ocr for --> 2425680151896856928.png
# getting ocr for --> 2342349126509138708.png
# getting ocr for --> 2353936860142998185.png
# getting ocr for --> 2333791347641638830.png
# getting ocr for --> 2347651152780474011.png
# getting ocr for --> 2348876611639877013.png
# getting ocr for --> 2352517526426362387.png
# getting ocr for --> 2375712551045810829.png
# getting ocr for --> 2339367505268858398.png
# getting ocr for --> 2341811246246264658.png
# getting ocr for --> 2345471679234661255.png
# getting ocr for --> 2335919366499381678.png
# getting ocr for --> 2338656797795442545.png
# getting ocr for --> 2344058177622328169.png
# getting ocr for --> 2333934134458500998.png
# i --> 20
# waiting for 63 seconds...
# getting ocr for --> 2394697772478837224.png
# getting ocr for --> 2365767204584534259.png
# getting ocr for --> 2372206354409755634.png
# getting ocr for --> 2341058865957138838.png
# getting ocr for --> 2338656797770232239.png
# getting ocr for --> 2373510558827043888.png
# getting ocr for --> 2425680151913681212.png
# getting ocr for --> 2435456592620377387.png
# getting ocr for --> 2351991123641481952.png
# getting ocr for --> 2350389633860575233.png
# getting ocr for --> 2393808657625551562.png
# getting ocr for --> 2359986520708155107.png
# getting ocr for --> 2422785836065371052.png
# getting ocr for --> 2425268245751093734.png
# getting ocr for --> 2349788573764790476.png
# getting ocr for --> 2343172003437263671.png
# getting ocr for --> 2350598473239542497.png
# getting ocr for --> 2332331152127719574.png
# getting ocr for --> 2359986520683068201.png

# %% [markdown]
# ## Look at combined ocr_dfs of instagram post text extraction
#
# - Text extracted for 602 images:

# %%
pd.concat(dfs)
# Out:
#    language  text_angle orientation  \
# 0        en         0.0          Up
# 0        en         0.0          Up
# 0        en         0.0          Up
# 0        en         0.0          Up
# 0        en         0.0          Up
# ..      ...         ...         ...
# 0        en         0.0          Up
# 0        en         0.0          Up
# 0        en         0.0          Up
# 0        en         0.0          Up
# 0        en         0.0          Up
#
#                                               regions               postId
# 0   {'bounding_box': '50,115,691,619', 'lines': [{...  2350613102216966045
# 0   {'bounding_box': '73,217,939,814', 'lines': [{...  2340140894484999761
# 0   {'bounding_box': '45,179,670,554', 'lines': [{...  2347618041418001201
# 0   {'bounding_box': '93,285,958,779', 'lines': [{...  2393806188103257343
# 0   {'bounding_box': '83,251,929,780', 'lines': [{...  2343348859268581716
# ..                                                ...                  ...
# 0   {'bounding_box': '72,203,670,535', 'lines': [{...  2349788573764790476
# 0   {'bounding_box': '81,351,931,680', 'lines': [{...  2343172003437263671
# 0   {'bounding_box': '55,173,662,557', 'lines': [{...  2350598473239542497
# 0   {'bounding_box': '12,81,1052,934', 'lines': [{...  2332331152127719574
# 0   {'bounding_box': '74,118,938,913', 'lines': [{...  2359986520683068201
#
# [602 rows x 5 columns]

# %% [markdown]
# ## *UPDATE -->> I exported the results to json, so not going to run again...*
# - The above cell for OCR w/ rate limiting takes around 33 minutes to complete

# %%
#final_df = pd.concat(dfs)
#final_df.reset_index(drop=True,inplace=True)
#final_df.to_json('ig_ocr.json')

final_df = pd.read_json('./data/ig_ocr.json')

# %%
final_df
# Out:
#     language  text_angle orientation  \
# 0         en         0.0          Up
# 1         en         0.0          Up
# 2         en         0.0          Up
# 3         en         0.0          Up
# 4         en         0.0          Up
# ..       ...         ...         ...
# 597       en         0.0          Up
# 598       en         0.0          Up
# 599       en         0.0          Up
# 600       en         0.0          Up
# 601       en         0.0          Up
#
#                                                regions               postId
# 0    {'bounding_box': '50,115,691,619', 'lines': [{...  2350613102216966144
# 1    {'bounding_box': '73,217,939,814', 'lines': [{...  2340140894484999680
# 2    {'bounding_box': '45,179,670,554', 'lines': [{...  2347618041418001408
# 3    {'bounding_box': '93,285,958,779', 'lines': [{...  2393806188103257088
# 4    {'bounding_box': '83,251,929,780', 'lines': [{...  2343348859268581888
# ..                                                 ...                  ...
# 597  {'bounding_box': '72,203,670,535', 'lines': [{...  2349788573764790272
# 598  {'bounding_box': '81,351,931,680', 'lines': [{...  2343172003437263872
# 599  {'bounding_box': '55,173,662,557', 'lines': [{...  2350598473239542272
# 600  {'bounding_box': '12,81,1052,934', 'lines': [{...  2332331152127719424
# 601  {'bounding_box': '74,118,938,913', 'lines': [{...  2359986520683068416
#
# [602 rows x 5 columns]

# %% [markdown]
# __________
#
# ## Nested OCR text words as `txt` column

# %%
def ocr_expand(x):
        
    txt = []
    
    for line in x.regions['lines']:
        for word in line['words']:
            txt.append(word['text'])
            
    return txt

# %%
final_df['txt'] = final_df.apply(lambda x: ocr_expand(x), axis=1)

# %%
#final_df.drop(columns=['regions']).to_json('ig_ocr_txt.json')

# %%
final_df.txt
# Out:
# 0      [Once, her, roommate, found, out, that, I, spe...
# 1      [I'm, an, Afro-Latina, from, a, low-income, ur...
# 2      [Being, a, Black, engineering, student, at, Co...
# 3      [I, had, a, precept, with, a, '21, male, stude...
# 4      [Psafety, was, called, for, a, noise, complain...
#                              ...
# 597    [Needles, to, say, I, never, got, my, stuff, b...
# 598    [Brown, students, boast, of, their, progressiv...
# 599    [My, grade, was, published, while, sitting, ne...
# 600    [At, night,, there, was, a, guard, stationed, ...
# 601    [Last, semester, I, took, one, of, the, many, ...
# Name: txt, Length: 602, dtype: object

# %% [markdown]
# ### We now want to set our IvyLeague stop words to find references for each respective school ...
#
# helpful example for logic https://stackoverflow.com/questions/6531482/how-to-check-if-a-string-contains-an-element-from-a-list-in-python

# %% [markdown]
# ### Loop through each ivy & check if it's in the txt lower case...
#
# - I am guessing we will miss some examples for this, for example `upenn` or `penn's`

# %%
ivyleaguesToCheck = ['penn','brown','princeton','harvard','columbia','yale','columbia','cornell','dartmouth']

# %%
def ivyCheck(x,ivyToCheck):
    
    for txt in x.txt:
        if txt.lower() in ivyToCheck:            
            return txt.lower()
        else:
            # ignore
            continue

# %%
final_df['ivy'] = final_df.apply(lambda x: ivyCheck(x,ivyleaguesToCheck), axis=1)

# %% [markdown]
# ### Our BlackIvyStories OCR college value_counts:

# %%
final_df.ivy.value_counts()
# Out:
# princeton    93
# penn         57
# brown        48
# columbia     43
# cornell      42
# harvard      41
# dartmouth    21
# yale         14
# Name: ivy, dtype: int64

# %%
penn_row_filter = final_df.ivy == 'penn'

# %%
penn_df = final_df[penn_row_filter]

# %%
penn_df.head()
# Out:
#    language  text_angle orientation  \
# 11       en         0.0          Up
# 17       en         0.0          Up
# 20       en         0.0          Up
# 31       en         0.0          Up
# 40       en         0.0          Up
#
#                                               regions               postId  \
# 11  {'bounding_box': '68,114,944,917', 'lines': [{...  2374422979850657792
# 17  {'bounding_box': '83,284,931,747', 'lines': [{...  2358282383087974912
# 20  {'bounding_box': '73,216,939,815', 'lines': [{...  2343993744749285376
# 31  {'bounding_box': '80,284,932,747', 'lines': [{...  2341764308463485440
# 40  {'bounding_box': '74,183,938,848', 'lines': [{...  2342541965549375488
#
#                                                   txt   ivy
# 11  [One, of, my, (non-Black), friends, and, I, we...  penn
# 17  [Penn's, Undergraduate, Assembly, has, a, hist...  penn
# 20  [Being, Black, at, Penn, means, watching, most...  penn
# 31  [During, the, Africana, Summer, Institute,, a,...  penn
# 40  [He, did, several, other, things, during, my, ...  penn

# %% [markdown]
# ### Join the ocr text for further analysis...

# %%
' '.join(penn_df.txt.iloc[29])
# Out:
# 'I was followed by campus police for "trespassing" on my own campus upon leaving the library on a late night after studying. There were others who left the same time I did. None of them Black. No one else was questioned. Just me. - Penn 123 @blackivystories'

# %% [markdown]
# ## TODO -->>
#
# - take the 57 penn post URLs and run commentGetter w/ docker
# - postIds to reconstruct the public url
