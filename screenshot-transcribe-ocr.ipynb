# %% [markdown]
# # Microsoft Azure Computer Vision for Screenshot Transcription OCR
#
# ## Etienne P Jacquot - ASC SYSADMIN - epj@asc.upenn.edu
#
# > This notebook was originally for Instagram posts!
#
# ### [Quickstart: Computer Vision client library for Python](https://docs.microsoft.com/en-us/azure/cognitive-services/computer-vision/quickstarts-sdk/python-sdk)
# __________________
#
# To [install Azure CLI](https://pypi.org/project/azure-cli/) for Python on MacOS:
# - `pip install azure-cli`
#
# To [install Azure SDKs](https://docs.microsoft.com/en-us/azure/cognitive-services/Custom-Vision-Service/python-tutorial):
# - `pip install azure.cognitiveservices.vision.computervision`
# - `pip install azure-cognitiveservices-vision-customvision`
#
#
# ### On Azure I created an `ASC-ComputerVision` endpoint w/ Free tier (20/minute, 5k per month)
#
# Save your credentials to `configs/config.ini` and do not share!
#
# _________

# %%
import pandas as pd
import os

import configparser
import sys
import time

import requests

from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials

# %% [markdown]
# ## Set your directory with local images
#
# - For example, in aspillari's home directory on Jhub:

# %%
img_dir = '../../../aspillari@asc.upenn.edu/Github/ig_pennstories_ocr/img/'

# %% [markdown]
# ## Set your Azure access key & endpoint
#
# - this is your `./configs/config.ini`, specifically the **ASC-COMPUTERVISION** profile

# %%
# add azure Computer Vision key and endpoint to config.ini
azure_cred = {}
config = configparser.ConfigParser()

config.read('./configs/config.ini') # <--- add your Twitter API tokens to this file!
for item,value in config['ASC-COMPUTERVISION'].items():
    azure_cred[item]=value
    
# Azure Variables Here!
_url = azure_cred['endpoint'] # Here, paste your full endpoint from the Azure portal
_key = azure_cred['key1']  # Here, paste your primary key
_maxNumRetries = 10

# %% [markdown]
# ## Set your Azure ComputerVision API Client

# %%
computervision_client = ComputerVisionClient(_url, CognitiveServicesCredentials(_key))

# %% [markdown]
# ## Some Example Python code for running OCR with Azure
#
# For a helpful list of additional examples, please visit here: https://github.com/Azure-Samples/cognitive-services-quickstart-code/blob/master/python/ComputerVision/ComputerVisionQuickstart.py
#
#
# ### (EXAMPLE) *Computer Vision Quick Description for local image*
#
# This is a quick way to get a confidence interval on whether there is text in the image
#
# > Notice we turn the JPG image into bytes and pass as stream with `describe_image_in_stream`

# %%
'''
Describe an image - remote
This example describes the contents of an image with the confidence score.
'''
print("===== Describe an image - remote =====")
# Call API

local_image_printed_text_path = img_dir + '/' + screenshot_filenames[0]
local_image_printed_text = open(local_image_printed_text_path, "rb")

description_results = computervision_client.describe_image_in_stream(local_image_printed_text)

# Get the captions (descriptions) from the response, with confidence level
print("Description of remote image: ")
if (len(description_results.captions) == 0):
    print("No description detected.")
else:
    for caption in description_results.captions:
        print("'{}' with confidence {:.2f}%".format(caption.text, caption.confidence * 100))
# Out:
# ===== Describe an image - remote =====
# Description of remote image:
# 'text' with confidence 99.65%

# %% [markdown]
# ### (EXAMPLE) *Computer Vision Text Description for local image*:
#
# This will effectively extract text with associated confidence intervals:
#
# > Notice we turn the JPG image into bytes and pass as stream with `recognize_printed_text_in_stream`

# %%
'''
Recognize Printed Text with OCR - local
This example will extract, using OCR, printed text in an image, then print results line by line.
'''
print("===== Detect Printed Text with OCR - local =====")

#remote_printed_text_image_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/printed_text.jpg"
#remote_printed_text_image_url=remote_image_url

# Specify your local Image here:
# For Example: This is the index 0, the first row
local_image_printed_text_path = img_dir + '/' + screenshot_filenames[22]
local_image_printed_text = open(local_image_printed_text_path, "rb")

ocr_result_local = computervision_client.recognize_printed_text_in_stream(local_image_printed_text)
for region in ocr_result_local.regions:
    for line in region.lines:
        print("Bounding box: {}".format(line.bounding_box))
        s = ""
        for word in line.words:
            s += word.text + " "
        print(s)
print()
'''
END - Recognize Printed Text with OCR - local
'''
# Out:
# ===== Detect Printed Text with OCR - local =====
# Bounding box: 69,55,634,75
# HANGING CITY
# Bounding box: 69,168,471,75
# EYE SHRINE
# Bounding box: 68,271,692,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 68,343,678,52
# SCENE: BH EYE SHRINE I
# Bounding box: 53,593,198,44
# RIEBECK
# Bounding box: 365,579,1144,40
# I'm pretty sure we'll need the others for this next part. We'll need, you know...
# Bounding box: 363,628,139,29
# everyone.
# Bounding box: 345,733,616,39
# No rush! Take your time. It mightnotevenexisthere„.
# Bounding box: 343,958,230,39
# Should I begin?
# Bounding box: 449,1053,55,26
# Yes.
# Bounding box: 452,1102,110,36
# Not yet.
# Bounding box: 343,1282,447,40
# Ok, I'll wait until you're ready.
# Bounding box: 449,1503,55,26
# Yes.
# Bounding box: 341,1707,412,40
# You g-got it. I'll do my best!
# Bounding box: 345,1969,589,40
# I learned a lot, by the end of everything.
# Bounding box: 342,2125,1141,39
# The past is past, now, but that's... you know, that's okay! It's never really gone
# Bounding box: 343,2162,1166,40
# completely. The future is always built on the past, even if we won't get to see it.
# Bounding box: 343,2303,643,40
# Still, it's, um, time for something new, now.
# '\nEND - Recognize Printed Text with OCR - local\n'

# %% [markdown]
# ___________________
#
# ## Great, wow run Microsoft Azure OCR on the rest of your screenshots to get transcripts

# %%
screenshot_filenames = [item for item in os.listdir(img_dir) if item.endswith('.jpg')]

# %% [markdown]
# _______
#
# ## Looking at our Example OCR (local image text description content) in a DataFrame
#
# - one row represents one image file with OCR extracted

# %%
ocr_df = pd.DataFrame.from_dict(ocr_result_local.as_dict())

# %%
ocr_df
# Out:
#   language  text_angle orientation  \
# 0       en         0.0          Up
#
#                                              regions model_version
# 0  {'bounding_box': '50,55,1569,2326', 'lines': [...    2021-04-01

# %%
ocr_df.regions[0].keys()
# Out:
# dict_keys(['bounding_box', 'lines'])

# %% [markdown]
# ### We can see all the words extracted:
#
# Ideally you just take this list of strings (words) and punch into a txt or json file

# %%
ocr_text = []

for line in ocr_df.regions[0]['lines']:
    for word in line['words']:
        #print(word['text'])
        ocr_text.append(word['text'])
        
print(ocr_text)
# Out:
"https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/printed_text.jpg"
#remote_printed_text_image_url=remote_image_url

# Specify your local Image here:
# For Example: This is the index 0, the first row
local_image_printed_text_path = img_dir + '/' + screenshot_filenames[22]
local_image_printed_text = open(local_image_printed_text_path, "rb")

ocr_result_local = computervision_client.recognize_printed_text_in_stream(local_image_printed_text)
for region in ocr_result_local.regions:
    for line in region.lines:
        print("Bounding box: {}".format(line.bounding_box))
        s = ""
        for word in line.words:
            s += word.text + " "
        print(s)
print()
'''
END - Recognize Printed Text with OCR - local
'''

# %% [markdown]
# ## Updates for loop to print all lines:

# %%
dfs = []

i = 0

for screenshot in screenshot_filenames:
    
    print('getting ocr for local image -->',screenshot)
    
    # RATE LIMITING, CHECK IN BEGINNING OF THE LOOP
    if i == 20:
        print('i --> {}'.format(i))
        print('waiting for 63 seconds...')
        i=0
        time.sleep(63)
        
    else:
        # TRY TO READ LOCAL IMAGE FILE
        try:
            local_image_printed_text_path = img_dir + "{}".format(screenshot)
            local_image_printed_text = open(local_image_printed_text_path, "rb")
        except:
            print('oops! failed to open image...')
            sys.stderr.write()
            break
            
        # TRY TO GET AZURE OCR TEXT EXTRACTION
        try:
            ocr_result_local = computervision_client.recognize_printed_text_in_stream(local_image_printed_text)
            for region in ocr_result_local.regions:
                for line in region.lines:
                    print("Bounding box: {}".format(line.bounding_box))
                    s = ""
                    for word in line.words:
                        s += word.text + " "
                    print(s)
            print('-'*60)
            
            ocr_df = pd.DataFrame.from_dict(ocr_result_local.as_dict())
            #ocr_df['img_filename'] = url
            ocr_df['postId'] = screenshot.strip('.jpg')
            dfs.append(ocr_df)
            i = i + 1
        except:
            print('oops! failed to get azure ocr...')
            sys.stderr.write()
            break
# Out:
# getting ocr for local image --> OW_Script_v3_pt2_Page_01.jpg
# Bounding box: 51,55,1039,75
# ESKER - LUNAR OUTPOST
# Bounding box: 50,212,542,49
# PLANET: ATTLEROCK
# Bounding box: 50,284,567,51
# SCENE: AR ESKAR I
# Bounding box: 50,485,387,45
# FELDSPAR Whoa!
# Bounding box: 341,580,1258,39
# Where'd you come from? No one's come here in... well, ever, actually. That makes you
# Bounding box: 341,618,1233,35
# the second Hearthian to ever reach Dark Bramble — after me, of course. Well done!
# Bounding box: 341,711,1241,40
# ...Say, it's you! They made you an astronaut? And you haven't blown yourself up yet,
# Bounding box: 341,749,193,39
# good for you!
# Bounding box: 450,843,296,37
# Feldspar! You're alive!
# Bounding box: 448,893,520,35
# We all thought you were dead for sure.
# Bounding box: 450,941,681,36
# Have you been here in Dark Bramble all this time?
# Bounding box: 341,1079,755,39
# ...You never were the brightest hatchling, were you.
# Bounding box: 340,1204,1148,39
# Yeah, that's right, I'm alive. Been camping out here since my ship, uh, y'know.
# Bounding box: 341,1242,285,39
# Crashed. Violently.
# Bounding box: 448,1336,164,32
# Wait, what?
# Bounding box: 447,1385,835,36
# You crashed? But you're the greatest pilot in Hearthian history!
# Bounding box: 341,1523,1278,40
# Oh, this is a good story. I'd just finished exploring the core of Giant's Dee and needed
# Bounding box: 341,1535,1229,65
# a new challenge, and none of us had ever been inside Dark Bramble, so I tkink, hey,
# Bounding box: 342,1598,281,40
# let's give that a try.
# Bounding box: 343,1706,1244,39
# I've been cruising around for a while, dodging the odd massive, interdimensional vine
# Bounding box: 342,1744,1237,39
# bristling with thorns, when I run into this huge anglerfish, the biggest I've ever seen.
# Bounding box: 343,1846,1269,40
# I pull a few stunts, try to shake the thing off — nothing too fancy. I'm going full-speed
# Bounding box: 340,1884,765,39
# when the fish clips me, knocks me into a vine, and...
# Bounding box: 341,1997,1233,45
# ...well, like I said, I crash. Blammo! On impact, my ship starts making noises like it's
# Bounding box: 341,2035,1256,39
# coming apart from the inside, and I think, well, that ain't great. Sure enough, I barely
# Bounding box: 341,2072,1024,40
# get out of there before the electrical systems start sparking like crazy.
# Bounding box: 343,2170,1233,40
# It's either move fast or die unpleasantly, so I had to put a little distance between me
# Bounding box: 341,2208,349,39
# and my poor, fried ship.
# Bounding box: 343,2304,1209,40
# I camped out near where I crashed at first. I found this skeleton later — great find,
# Bounding box: 340,2339,502,42
# woul&ve been stupid not to use it.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_03.jpg
# Bounding box: 69,55,1039,75
# ESKER - LUNAR OUTPOST
# Bounding box: 68,212,542,49
# PLANET: ATTLEROCK
# Bounding box: 68,284,575,51
# SCENE: AR ESKAR 3
# Bounding box: 43,485,232,45
# FELDSPAR
# Bounding box: 447,647,835,36
# You crashed? But you're the greatest pilot in Hearthian history!
# Bounding box: 343,734,1223,40
# I haven't lived in polite society for a while, so I'm just going to go ahead and assume
# Bounding box: 341,772,297,28
# that wasn't sarcasm.
# Bounding box: 448,975,909,36
# "Got stuck"? But aren't you the greatest pilot in Hearthian history?
# Bounding box: 343,1064,455,39
# Haha, you flatter me! ...l like it!
# Bounding box: 343,1201,1198,40
# I came to Dark Bramble for the excitement. I'd just finished exploring the core of
# Bounding box: 341,1239,1247,39
# Giant's Deep and needed a new challen e, and none of us had ever gone farther than
# Bounding box: 343,1250,894,66
# Dark Bramble's ice fields, so I thought, key, let's give it a try.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_04.jpg
# Bounding box: 64,55,1039,75
# ESKER - LUNAR OUTPOST
# Bounding box: 63,212,542,49
# PLANET: ATTLEROCK
# Bounding box: 63,284,510,51
# SCENE: AR ESKÄR
# Bounding box: 32,485,233,45
# FELDSPAR
# Bounding box: 341,565,1249,40
# So I moved my setup over here and planted my emergency tree seeds. Been here ever
# Bounding box: 341,603,83,28
# since!
# Bounding box: 448,697,99,27
# ...Wow.
# Bounding box: 450,746,383,36
# I can't believe you didn't die.
# Bounding box: 450,795,517,36
# I can't believe you destroyed your ship.
# Bounding box: 450,843,792,37
# No wonder there are so many stories about you back home!
# Bounding box: 340,943,284,38
# Yeah, pretty much.
# Bounding box: 360,1091,473,37
# @ I can't believe you didn't die.
# Bounding box: 339,1215,1267,40
# You know, in the old days, I used to think the same thing every time I came back from
# Bounding box: 341,1253,299,39
# a flight in one piece.
# Bounding box: 340,1362,379,39
# These days, I'm used to it.
# Bounding box: 450,1468,517,34
# I can't believe you destroyed your ship.
# Bounding box: 343,1563,1159,46
# Easy for you to say. Your ship probably has all kinds of fancy modifications and
# Bounding box: 341,1601,1236,39
# upgrades, like "working retro boosters and "non-flammable construction materials."
# Bounding box: 450,1753,792,37
# No wonder there are so many stories about you back home!
# Bounding box: 343,1866,918,40
# Heh. You're not half-bad yourself, making it here in one piece.
# Bounding box: 340,2040,699,39
# Anyway, that's how it all went down, hatchling!
# Bounding box: 341,2186,867,39
# Story's over, but feel free to stay and enjoy the fire a while.
# Bounding box: 341,2352,529,39
# Or don't. Fire's not going anywhere.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_05.jpg
# Bounding box: 59,55,562,75
# EYE LOCATOR
# Bounding box: 58,212,542,49
# PLANET: ATTLEROCK
# Bounding box: 58,284,741,51
# SCENE: AR EYE LOCATOR I
# Bounding box: 35,486,156,44
# CHERT
# Bounding box: 341,503,912,39
# Goodness, it's you! Hello! I take it your first launch went well,
# Bounding box: 343,540,556,39
# Hourglass Twins. Mind the sand, now.
# Bounding box: 450,635,336,36
# I have a question for you.
# Bounding box: 448,683,270,36
# What are you up to.
# Bounding box: 1262,503,329,28
# then? Welcome to the
# Bounding box: 343,793,1241,39
# Hornfels asked me to update our star charts, so I'm out here observing. This is one of
# Bounding box: 341,831,1079,39
# the best places in the solar system to spot astronomical events, you know.
# Bounding box: 341,936,1144,39
# What's weird is I've actually seen a couple of supernovae today. Usually, I'd be
# Bounding box: 341,972,1236,41
# fortunate to see just one. Keep an eye or two on the stars, and maybe you'll spot one
# Bounding box: 340,1011,128,40
# yourself!
# Bounding box: 340,1126,454,40
# Tell me, what can I do for you?
# Bounding box: 450,1221,254,36
# I found something!
# Bounding box: 450,1270,573,36
# How do I know if I've spotted a supernova?
# Bounding box: 341,1365,1253,39
# Supernovae look like extra bri ht stars to the naked eye, but if you zoom in with your
# Bounding box: 341,1403,972,39
# signalscope you can tell that t ey're actually enormous explosions.
# Bounding box: 341,1497,1185,45
# Massive stars go supernova at the very end of their life spans, which is why it's so
# Bounding box: 341,1535,496,39
# unusual to see two In a single day.
# Bounding box: 343,1651,846,29
# I wonder if some of these stars are older than we realized?
# Bounding box: 448,1760,399,36
# What are you doing out here?
# Bounding box: 343,1837,1247,39
# Right now I'm documenting stars. Hornfels noticed our star charts are out of date, so
# Bounding box: 341,1875,457,39
# they asked me to update them.
# Bounding box: 343,1971,1250,39
# Please don't tell the others I said this, but sometimes I think I'm the only traveler out
# Bounding box: 342,2009,617,39
# here interested in doing any science at all.
# Bounding box: 341,2113,1113,40
# ...Er, maybe don't tell Hornfels, either. I think they're pretty deep in denial.
# Bounding box: 448,2236,393,36
# Where should I explore here?
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_06.jpg
# Bounding box: 74,55,896,75
# EYE LOCATOR SCROLL
# Bounding box: 73,212,542,49
# PLANET: ATTLEROCK
# Bounding box: 73,284,750,51
# SCENE: AR EYE LOCATOR 2
# Bounding box: 93,486,156,44
# CHERT
# Bounding box: 448,536,393,36
# Where should I explore here?
# Bounding box: 340,623,1275,45
# To be honest, I haven't left this lakebed. I don't mean to brag, but I'm really quite good
# Bounding box: 340,655,1255,45
# with the Little Scout, so I've been taking pictures of everything from right here in my
# Bounding box: 341,699,140,39
# campsite.
# Bounding box: 343,805,1236,39
# Have you seen the old shipwreck site on the Ember Twin's southern hemisphere, the
# Bounding box: 341,842,1182,40
# one shooting a bright beam of light into the sky? It's not one of our own crashes,
# Bounding box: 341,880,669,40
# surprisingly enough - this one's a Nomai ship.
# Bounding box: 339,992,1181,39
# You'll find Nomai ruins across the Twins, but, strangely, not a single settlement!
# Bounding box: 343,1029,1061,40
# Believe me, if there was one to see, I'd have seen it with my Little Scout.
# Bounding box: 341,1148,1203,39
# So where did they live? Not on the surface, clearly. The Ember Twin is full of cave
# Bounding box: 341,1186,807,39
# systems, though - maybe the answer lies underground?
# Bounding box: 450,1282,672,36
# How dangerous is that big column of falling sand?
# Bounding box: 341,1370,1130,40
# On a scale of one to dead, I'd give it a seven or eight. Awfully pretty, though.
# Bounding box: 343,1471,1275,39
# Right now sand is flowing from Ash Twin to Ember Twin, but did you know the process
# Bounding box: 341,1508,1200,40
# eventually reverses? We're not com letely sure why the sand flows back and forth
# Bounding box: 342,1546,883,40
# between the Twins, but it seems to e a natural phenomena.
# Bounding box: 341,1648,1233,39
# Oh, if you'd like to see something interesting, check out the other Twin once a little
# Bounding box: 342,1686,940,39
# more of its sand drains off. I promise you won't be disappointed.
# Bounding box: 341,1792,1238,39
# Watch out for falling sand, okay? I've had to dig myself out once or twice, and that's
# Bounding box: 342,1829,402,29
# not half as fun as it sounds.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_07.jpg
# Bounding box: 69,63,1080,69
# RIEBECK - ATTLEROCK NOTES
# Bounding box: 68,212,543,49
# PLANET: ATTLEROCK
# Bounding box: 68,284,749,51
# SCENE: AR EYE LOCATOR 3
# Bounding box: 71,564,156,44
# CHERT
# Bounding box: 450,622,254,36
# I found something!
# Bounding box: 343,727,212,39
# Please, do tell!
# Bounding box: 450,826,709,36
# I found your notes about the Attlerock's main crater.
# Bounding box: 343,948,494,40
# Did you! I hope they were useful?
# Bounding box: 340,1061,1267,39
# The lanet I mentioned may have been frozen solid, or just partially made of ice, like a
# Bounding box: 342,1099,1237,39
# muc colder Giant's Deep - it's hard to say. It used to be the fifth planet in our solar
# Bounding box: 341,1143,110,33
# system.
# Bounding box: 340,1236,1251,39
# You'll notice, of course, that there's no such planet now. In its place is Dark Bramble,
# Bounding box: 340,1274,1131,39
# which - how to put this - grew into the space the fifth planet used to occupy.
# Bounding box: 340,1389,1214,39
# That is, Dark Bramble quite literally appeared at the center of the fifth planet and
# Bounding box: 342,1426,1252,40
# be an destroying it from the inside-out. Eventually, the planet shattered completely,
# Bounding box: 341,1464,560,40
# an its shards were flung across space.
# Bounding box: 341,1580,1262,39
# Some of these shards collided with the celestial bodies in our solar system, such as the
# Bounding box: 340,1617,918,40
# Attlerock, which I believe is how its biggest crater was formed.
# Bounding box: 450,1723,611,36
# I found Nomai writing about a hidden planet.
# Bounding box: 343,1823,1270,39
# How fascinatin ! It might interest you to know the existence of an additional planet is
# Bounding box: 340,2000,1271,39
# And honestly, we don't know all that much about what's out there. The farther you go,
# Bounding box: 341,2037,1261,40
# the less we know! As such, it's well within the realm of possibility such a planet exists.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_08.jpg
# Bounding box: 60,55,1116,75
# CHERT - ATTLEROCK NOTES
# Bounding box: 63,212,543,49
# PLANET: ATTLEROCK
# Bounding box: 63,284,647,51
# SCENE: AR ICE SHARDS
# Bounding box: 85,661,155,44
# CHERT
# Bounding box: 450,755,673,36
# I found Nomai writing about the Quantum Moon.
# Bounding box: 341,830,1199,39
# Oh yes, everyone loves a good mystery, don't the ? Who wouldn't wonder about a
# Bounding box: 342,868,722,28
# moon that's sometimes there and sometimes not.
# Bounding box: 343,949,1246,39
# I've observed the Quantum Moon orbiting each of the five planets, but sometimes, it
# Bounding box: 341,986,1271,40
# quite simply disappears from the sky altogether. Maybe there's another place it travels
# Bounding box: 341,1024,40,29
# to!
# Bounding box: 342,1128,1274,39
# Unfortunately, if there is, I've never seen it. Perhaps if I take a closer look at these star
# Bounding box: 341,1166,116,28
# charts...
# Bounding box: 450,1284,615,36
# I found Nomai writing about the Sun Station.
# Bounding box: 343,1371,1147,40
# Is that what's in orbit around the sun, then, do you think? This... Sun Station?
# Bounding box: 341,1455,1230,39
# Quite clever of the Nomai to devise a way to study the sun up close and personal! It
# Bounding box: 342,1492,1178,40
# must have been tremendously difficult to construct. ...And hot inside. I can only
# Bounding box: 341,1530,126,40
# imagine!
# Bounding box: 343,1637,1218,39
# I wonder how were they able to travel back and forth from the Sun Station and the
# Bounding box: 343,1675,1111,39
# Hourglass Twins, when the slightest slip up would have meant a fiery death.
# Bounding box: 450,1975,672,28
# rtow dangerous IS that big column ot talllng sand'
# Bounding box: 447,2016,192,36
# Just saying hi.
# Bounding box: 341,2090,1238,40
# Watch out for falling sand, okay? I've had to dig myself out once or twice, and that's
# Bounding box: 342,2128,402,28
# not half as fun as it sounds.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_09.jpg
# Bounding box: 79,55,1070,75
# ESKER SIGNALSCOPE LOG
# Bounding box: 78,212,543,49
# PLANET: ATTLEROCK
# Bounding box: 78,284,674,52
# SCENE: AR NORTH POLE
# Bounding box: 79,618,156,44
# CHERT
# Bounding box: 343,591,1137,44
# Hm? Oh, it's you! I take it your first launch went well, then? Welcome to the
# Bounding box: 343,628,556,39
# Hourglass Twins. Mind the sand, now.
# Bounding box: 450,723,336,36
# I have a question for you.
# Bounding box: 448,771,274,37
# What are you up to?
# Bounding box: 343,845,1223,40
# Hornfels noticed our star charts are out of date, so I came out here to update them.
# Bounding box: 343,883,657,39
# But something seems... how to put this... off.
# Bounding box: 343,977,1260,39
# I've seen, what, ten supernovae by now? Twelve? They're in the double digits now, and
# Bounding box: 341,1014,717,40
# that's, you know, not normal. Not normal at all...
# Bounding box: 448,1122,558,36
# Why are so many stars going supernovae?
# Bounding box: 343,1226,1264,39
# I have no idea! Massive stars go supernova when they reach the end of their life spans,
# Bounding box: 341,1264,1285,39
# so it's possible that the stars are older than we realized. Or maybe our models are wrong
# Bounding box: 341,1301,619,40
# and they don't live as long as we expected.
# Bounding box: 343,1405,1227,39
# Honestly, I'm not fond of either option! If our charts are wrong, what else is wrong?
# Bounding box: 340,1442,207,29
# And our sun...
# Bounding box: 343,1555,1260,40
# No, I shouldn't jump to conclusions. l- I'm probably overlooking something. That's it, I
# Bounding box: 335,1593,450,39
# just need to collect more data.
# Bounding box: 447,1826,191,36
# Just saying hi.
# Bounding box: 341,1965,555,36
# Watch out for the stars. I mean, sand.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_10.jpg
# Bounding box: 74,55,818,75
# BLACK HOLE FORGE
# Bounding box: 73,212,692,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 73,284,907,51
# SCENE: BH BLACK HOLE FORGE I
# Bounding box: 61,602,155,44
# CHERT
# Bounding box: 450,581,615,36
# I found Nomai writing about the Sun Station.
# Bounding box: 450,629,882,36
# I found modern Nomai transmissions saying the universe is dying.
# Bounding box: 448,678,282,36
# Actually, nevermind.
# Bounding box: 339,833,484,29
# You - what? I don't... um. What?
# Bounding box: 340,993,1284,39
# You mean to say there are modern Nomai out in other parts of space? And they believe
# Bounding box: 341,1030,1102,40
# the universe - all of it, the whole thing - is dying? Currently? ...Right now?
# Bounding box: 343,1195,1251,39
# If... if that's true, how could I have missed so many signs? The supernovae were there,
# Bounding box: 342,1232,1136,40
# but I, but, I've been studying the stars for... well, what does it matter if... oh...
# Bounding box: 343,1401,1206,40
# I'm very sorry, b-but I have to look over my charts. I h-h-hope you don't m-mind...
# Bounding box: 343,1785,1202,39
# B-b-but surely, I would have seen some kind of other sign than the supernovae, so
# Bounding box: 342,1823,189,39
# p-perhaps.„?
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_11.jpg
# Bounding box: 37,55,1157,75
# BLACK HOLE FORGE SCROLL
# Bounding box: 36,212,691,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 36,284,915,51
# SCENE: BH BLACK HOLE FORGE 2
# Bounding box: 63,575,156,44
# CHERT
# Bounding box: 340,555,1245,39
# The stars! They're all dying! There've been too many supernovae for it to be anything
# Bounding box: 341,593,65,28
# else!
# Bounding box: 341,728,1049,39
# We're next, do you understand?! Our sun! By Hearth's name, we're next!
# Bounding box: 448,829,447,36
# What do you mean, "we're next"?
# Bounding box: 343,921,1273,39
# It's the stars, you see. All the other stars are dying out. Oh, why did we have to be born
# Bounding box: 341,958,650,36
# at the end of the universe? And our sun, it...
# Bounding box: 340,1058,1272,39
# The star charts! Why? Why did I want to update them so badl ? I didn't have to know,
# Bounding box: 342,1096,1271,39
# but no, oh no, I had to update the star charts! I had to go looking for things I shouldn't
# Bounding box: 342,1133,754,29
# have! And now our sun is about to... about to... oh...
# Bounding box: 341,1233,657,40
# ...l don't feel well. I'd like to be alone, please.
# Bounding box: 450,1375,254,36
# I found something!
# Bounding box: 341,1482,1282,40
# Why, isn't that great! Do you know what, I've found a few things myself! Most of them
# Bounding box: 342,1521,504,39
# have to do with the sun exploding!
# Bounding box: 341,1614,1279,39
# Oh, who cares?! What does it matter?! Nothing matters anymore! The sun is about to go
# Bounding box: 341,1650,864,40
# supernova! And me, all my research, my life's work, wasted!
# Bounding box: 341,1758,545,55
# Wasted, you understand?!
# Bounding box: 448,1886,334,36
# Why are the stars dying?
# Bounding box: 343,1989,1237,40
# I don't know — they're old! Far older than we realized and now all of them are dying!
# Bounding box: 341,2116,1263,39
# What does it matter?! It doesn't! It doesn't matter at all! Nothing matters anymore! All
# Bounding box: 342,2153,521,39
# my research, my life's work, wasted!
# Bounding box: 341,2260,545,55
# Wasted, you understand?!
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_12.jpg
# Bounding box: 37,55,1110,75
# BLACK HOLE FORGE ALIGN
# Bounding box: 36,212,691,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 36,284,914,51
# SCENE: BH BLACK HOLE FORGE 3
# Bounding box: 69,708,155,44
# CHERT
# Bounding box: 448,828,399,37
# What are you doing out here?
# Bounding box: 340,902,1272,35
# The star charts! It's all the star charts' fault! I didn't have to know, but no, oh no, I had
# Bounding box: 341,939,1261,46
# to update the star charts! I had to go looking for things I shouldn't have! And now our
# Bounding box: 341,977,469,29
# sun IS about to... about to... oh...
# Bounding box: 448,1071,393,36
# Where should I explore here?
# Bounding box: 341,1158,1115,39
# Where should you go? Where can anyone go? Can't you see it's too late now?
# Bounding box: 450,1281,672,37
# How dangerous is that big column of falling sand?
# Bounding box: 343,1421,1034,40
# Not as dangerous as what's about to happen to our entire solar system!
# Bounding box: 389,1571,930,40
# I don't feel well. I'd like to be alone, please. I can't believe this...
# Bounding box: 360,1738,278,36
# (8) Just saying hi.
# Bounding box: 343,1890,1229,39
# I can't believe this. I can't believe this is happening. I can't... I won't! I won't believe it!
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_13.jpg
# Bounding box: 60,55,786,75
# FORGE ASH TABLET
# Bounding box: 341,161,164,36
# Oh, hello...
# Bounding box: 59,211,691,50
# PLANET: BRITTLE HOLLOW
# Bounding box: 59,284,1457,52
# SCENE: sit together and watch the stars die.
# Bounding box: 448,392,194,36
# Sure, why not.
# Bounding box: 450,440,714,37
# If it helps, we're in a time loop, so we won't really die.
# Bounding box: 450,489,156,32
# No, thanks.
# Bounding box: 341,667,1147,40
# We only get so much time, don't we? Ah, there was still more I wanted to do...
# Bounding box: 343,805,860,40
# How unlucky to have been born at the end of the universe.
# Bounding box: 340,1000,271,39
# Any minute now...
# Bounding box: 360,1153,246,32
# (8) No, thanks.
# Bounding box: 343,1273,1012,40
# Perhaps you're right. ...Yes, we should face this alone. That's the way.
# Bounding box: 341,1373,726,35
# We enter this world alone, and we leave it alone...
# Bounding box: 340,1530,271,40
# Any minute now...
# Bounding box: 450,1689,714,37
# If it helps, we're in a time loop, so we won't really die.
# Bounding box: 340,1816,933,40
# Ah, that's a lovely thought. Is that how you're coping with this?
# Bounding box: 84,2076,156,44
# CHERT
# Bounding box: 343,1910,192,40
# Does it help?
# Bounding box: 340,2076,576,40
# A time loop, you said? I like that idea...
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_14.jpg
# Bounding box: 45,102,1030,74
# FORGOTTEN SETTLEMENT
# Bounding box: 41,214,481,74
# MIGRATION
# Bounding box: 44,316,687,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 44,388,1007,52
# SCENE: BH FORGOTTEN SETTLEMENT
# Bounding box: 341,464,1191,39
# Nice, it's you. Good to see you made it here in one piece. The first solo launch is a
# Bounding box: 339,494,212,47
# doozy, isnst it?
# Bounding box: 339,616,1247,40
# So hey, don't freak out or anything, but lately I keep, like, dying repeatedly. I dunno,
# Bounding box: 339,654,240,39
# it's pretty weird.
# Bounding box: 348,750,807,40
# What about you? Have you died lately, or is it just me?
# Bounding box: 457,844,498,36
# No, it's me, too. We're in a time loop.
# Bounding box: 347,937,1131,39
# Time has been behaving unusually lately. Yeah, a time loop makes sense. Cool.
# Bounding box: 454,1031,398,36
# You're taking this pretty well.
# Bounding box: 350,1117,338,39
# Heh, right back at you.
# Bounding box: 350,1209,1229,39
# Personally, I like new experiences, and I've never been in a time loop before. I mean, I
# Bounding box: 348,1246,731,39
# don't think I've been in a time loop before this one.
# Bounding box: 350,1337,1243,39
# It looks like you and I are the only ones who can tell that time's one all weird. I tried
# Bounding box: 349,1348,1136,66
# radioing Hornfels and asking if they'd died, too, but they though I was being
# Bounding box: 349,1412,201,39
# metaphorical.
# Bounding box: 350,1505,1278,39
# Even if I tell Hornfels about the time loop, they never remember by the next one. They
# Bounding box: 348,1543,488,39
# don't realize anything's different.
# Bounding box: 347,1635,1253,39
# And here's another weird one for you - eve time I die, all of my memories from that
# Bounding box: 349,1672,1240,40
# loop replay back to me. I'm pretty sure that s related to this big stone Nomai statue I
# Bounding box: 348,1710,494,29
# found on one of the other islands.
# Bounding box: 350,1802,1248,39
# I was lookin at it, and the statue opened its eyes and started glowing. It replayed my
# Bounding box: 349,1813,1260,66
# memories lik it'd seen them through my own eyes, just like what happens each time I
# Bounding box: 348,1877,52,29
# die.
# Bounding box: 454,1972,717,36
# That happened to me with the statue at the museum.
# Bounding box: 346,2047,1263,39
# You too, huh? Then the Nomai statues must have something to do with why we're the
# Bounding box: 348,2084,1198,40
# only ones aware of the time loop. So... no glowing statue, no time loop awareness?
# Bounding box: 350,2185,1225,39
# I think that's going to be my leading theory, but if you find out anything new about
# Bounding box: 348,2223,878,39
# the statues or the time loop, let me know, okay? I'll be here.
# Bounding box: 455,2326,363,35
# What did you think it was?
# Bounding box: 350,2384,1251,40
# I figured it'd be some kind of fid ety time business, but I wasn't really thinking about
# Bounding box: 347,2423,1246,39
# what's happening to the shape o time, you know? But a loop makes sense here. Let's
# Bounding box: 348,2460,338,39
# go with "loop" for now.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_15.jpg
# Bounding box: 55,55,580,75
# ESCAPE POD I
# Bounding box: 54,212,691,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 54,284,708,51
# SCENE: BH ESCAPE POD I
# Bounding box: 342,467,1192,40
# Nice, it's you. Good to see you made it here in one piece. The first solo launch is a
# Bounding box: 188,497,364,47
# B doozy, isnst it?
# Bounding box: 340,613,1212,39
# So hey, don't laugh, but I think I might have had some kind of spiritual experience
# Bounding box: 339,650,440,40
# with a rock shaped like a face.
# Bounding box: 358,745,203,27
# @ ...What?
# Bounding box: 448,794,104,26
# Me too!
# Bounding box: 340,978,1272,39
# One of the islands on Giant's Deep has a Nomai statue on the beach - ever seen one? I
# Bounding box: 341,1016,1235,39
# brought one back to Timber Hearth with me. Big stone sculpture of a Nomai's head,
# Bounding box: 340,1053,740,40
# three eyes and everything. Beautifully carved, too.
# Bounding box: 341,1191,1232,45
# So one minute I'm standing on an island looking at a Nomai sculpture on the beach,
# Bounding box: 340,1229,868,39
# and the next thing I know, It's looking back at me, glowing.
# Bounding box: 339,1323,1263,39
# The sculpture replays everything I've just done, like it's been watching me through my
# Bounding box: 340,1361,1170,39
# own eyes, you know? And then suddenly it stops and everything's normal again.
# Bounding box: 446,1456,547,36
# That ha pened to me at the observatory.
# Bounding box: 342,1592,1145,39
# It didn't seem bad, just... weird? Were we the only ones who saw that happen?
# Bounding box: 342,1699,1240,40
# I tried radioing Hornfels and asking them about it, but they told me I must have just
# Bounding box: 341,1737,610,38
# nodded off out here and gotten confused.
# Bounding box: 339,1850,1279,39
# Then we talked about dreams until Hornfels told me to go refill my oxygen tank before
# Bounding box: 342,1888,357,39
# I talked myself to death.
# Bounding box: 340,1994,1231,40
# So that's what's new with me. But hey, this is your first solo voyage! Let's talk about
# Bounding box: 339,2032,228,39
# you, you know?
# Bounding box: 448,2129,104,26
# Me too!
# Bounding box: 338,2226,1285,40
# You're saying the statue I brought to the museum started glowing at you? Yeah, sounds
# Bounding box: 340,2262,172,41
# about right.
# Bounding box: 340,2361,1262,49
# One minute I'm standing on an island looking at a Nomai sculpture on the beach, and
# Bounding box: 340,2399,805,39
# the next thing I know, it s looking back at me, glowing.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_16.jpg
# Bounding box: 55,55,976,75
# ESCAPE POD WARNING
# Bounding box: 54,212,691,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 54,284,717,51
# SCENE: BH ESCAPE POD 2
# Bounding box: 48,522,217,45
# GABBRO
# Bounding box: 341,520,1213,40
# Okay, here's a weird one for you — I think I might have just, like, died? Somehow?
# Bounding box: 343,637,1260,40
# I radioed Hornfels at the observatory to ask them about it, but they're convinced I fell
# Bounding box: 341,675,707,39
# asleep out here and had a nightmare something.
# Bounding box: 343,773,902,40
# Do you remember, y'know, dying a few minutes ago? Maybe?
# Bounding box: 448,868,381,36
# Oh yeah, we definitely died.
# Bounding box: 450,917,504,36
# I think we're the only ones who know.
# Bounding box: 341,1056,1053,39
# Okay, cool, that's what I thought. It was all way too vivid to be a dream.
# Bounding box: 343,1175,1272,45
# I radioed Hornfels again to ask if they had died, too, but I'm pretty sure they thought I
# Bounding box: 340,1213,354,39
# was being metaphorical.
# Bounding box: 341,1308,1203,40
# Well, if you remember dying, then I guess I didn't just fall asleep and have a weird
# Bounding box: 341,1346,1255,39
# dream or something. But stars above, what's going on, then? And then there was that
# Bounding box: 341,1383,547,40
# thing with the Nomai statue earlier...
# Bounding box: 341,1486,1247,40
# Come to think of it, when I died, I saw what I'm pretty sure were my memories going
# Bounding box: 342,1524,1199,39
# backward, just like the time with that statue. Do you think the Nomai statues are
# Bounding box: 342,1561,433,40
# related to us dying somehow?
# Bounding box: 341,1707,1045,40
# So... we died, but we aren't dead? That's pretty unusual for Hearthians.
# Bounding box: 343,1845,1211,40
# I am goin to need to do some serious thinking before I come up with any theories.
# Bounding box: 341,1856,1016,66
# Maybe I'lFhave figured something out by the next time you come by.
# Bounding box: 450,2007,504,36
# I think we're the only ones who know.
# Bounding box: 1301,2056,9,14
# .7
# Bounding box: 339,2139,1223,42
# Yeah, I radioed Hornfels again to ask if they had died, too, but I'm pretty sure they
# Bounding box: 341,2177,501,39
# thought I was being metaphorical.
# Bounding box: 343,2393,1246,40
# Hey again. If you feel like roasting a mallow, feel free to use my campfire. It's just up
# Bounding box: 341,2429,317,41
# the path a little ways.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_17.jpg
# Bounding box: 89,55,1038,75
# FORGOTTEN SETTLEMENT
# Bounding box: 89,168,439,75
# ENTRANCE
# Bounding box: 88,271,691,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 88,343,1052,52
# SCENE: BH FORGOTTEN SETTLEMENT I
# Bounding box: 57,574,217,45
# GABBRO
# Bounding box: 343,590,912,39
# I was hoping you'd be back - something really weird is going on.
# Bounding box: 450,684,460,36
# Do you think we're in a time loop?
# Bounding box: 448,732,417,36
# We're definitely in a time loop.
# Bounding box: 339,858,1233,40
# Yeah, a time loop makes the most sense, right? Or at least, it's some kind of fidgety
# Bounding box: 341,896,1262,39
# time business. Hard to say what's happening to the shape of time, exactly, but let's go
# Bounding box: 340,933,295,40
# wtih "loop" for now.
# Bounding box: 341,1095,1258,39
# So it looks like ou and I are the only ones who know we're in a time loop. And even if
# Bounding box: 340,1133,1141,39
# you tell them a out it, no one remembers by the next loop. What's with that?
# Bounding box: 341,1269,1214,40
# Maybe it's because we both made some seriously intense eye contact with a Nomai
# Bounding box: 341,1307,107,28
# statue?
# Bounding box: 343,1430,1244,40
# I'm seeing my memories replay each time I die, just like I did when the Nomai statue
# Bounding box: 341,1468,1268,39
# on the beach o ened its eyes and looked at me. So maybe... no glowing statue, no time
# Bounding box: 342,1505,229,40
# loop awareness.
# Bounding box: 343,1651,1226,40
# I think that's going to be my leading theory, but if you find out anything new about
# Bounding box: 341,1689,880,39
# the statues or the time loop, let me know, okay? I'll be here.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_18.jpg
# Bounding box: 85,102,1039,75
# FORGOTTEN SETTLEMENT
# Bounding box: 85,215,471,75
# EYE SHRINE
# Bounding box: 83,319,693,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 84,391,1062,52
# SCENE: BH FORGOTTEN SETTLEMENT 2
# Bounding box: 79,568,217,45
# GABBRO
# Bounding box: 337,596,1285,40
# You're saying the statue I brought to the museum started glowing at you? Yeah, sounds
# Bounding box: 339,632,173,41
# about right.
# Bounding box: 338,859,1232,40
# Yeah, a time loop makes the most sense, right? Or at least, it's some kind of fidgety
# Bounding box: 339,897,1262,39
# time business. Hard to say what's happening to the shape of time, exactly, but let's go
# Bounding box: 339,934,295,40
# wtih "loop" for now.
# Bounding box: 339,1096,1258,39
# So it looks like ou and I are the only ones who know we're in a time loop. And even if
# Bounding box: 338,1134,1141,39
# you tell them a out it, no one remembers by the next loop. What's with that?
# Bounding box: 339,1270,1214,40
# Maybe it's because we both made some seriously intense eye contact with a Nomai
# Bounding box: 339,1308,107,28
# statue?
# Bounding box: 341,1431,1243,40
# I'm seeing my memories replay each time I die, just like I did when the Nomai statue
# Bounding box: 339,1469,1268,40
# on the beach o ened its eyes and looked at me. So maybe... no glowing statue, no time
# Bounding box: 340,1506,229,40
# loop awareness.
# Bounding box: 341,1652,1227,40
# I think that's going to be my leading theory, but if you find out anything new about
# Bounding box: 339,1690,879,39
# the statues or the time loop, let me know, okay? I'll be here.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_19.jpg
# Bounding box: 75,102,1038,75
# FORGOTTEN SETTLEMENT
# Bounding box: 69,215,658,75
# VESSEL MURALS
# Bounding box: 74,319,691,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 74,391,1060,52
# SCENE: Bf-I FORGOTTEN SETTLEMENT 3
# Bounding box: 341,533,1192,40
# Nice, it's vou. Good to see you made it here in one piece. The first solo launch is a
# Bounding box: 52,546,217,45
# GABBRO
# Bounding box: 339,571,212,39
# doozy, isn t it?
# Bounding box: 339,703,1054,40
# So hey, don't laugh, but I think I might have just, like, died? Somehow?
# Bounding box: 341,835,902,39
# Do you remember, y'know, dying a few minutes ago? Maybe?
# Bounding box: 446,930,381,36
# Oh yeah, we definitely died.
# Bounding box: 448,979,504,36
# I think we're the only ones who know.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_20.jpg
# Bounding box: 64,102,1038,75
# FORGOTTEN SETTLEMENT
# Bounding box: 64,215,435,75
# ILEX POEM
# Bounding box: 63,319,691,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 63,391,1320,52
# SCENE: BH FORGOTTEN SETTLEMENT MEMORIES
# Bounding box: 53,590,156,44
# CHERT
# Bounding box: 344,600,1219,39
# The stars were beautiful, weren't they? Even if our star is what ultimately killed us.
# Bounding box: 347,769,909,40
# I'll wait here and remember them while you gather everybody.
# Bounding box: 345,953,201,39
# Shall I begin?
# Bounding box: 451,1048,56,26
# Yes.
# Bounding box: 454,1097,110,36
# Not yet.
# Bounding box: 344,1277,982,40
# Take your time! I don't think there's anything left to go supernova.
# Bounding box: 451,1498,56,26
# Yes.
# Bounding box: 345,1704,311,39
# Well, then, here I go!
# Bounding box: 347,1965,704,40
# Even if it's over now, I had a good time learning.
# Bounding box: 347,2139,606,40
# But I think the rules are about to change.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_21.jpg
# Bounding box: 51,55,1038,74
# FORGOTTEN SETTLEMENT
# Bounding box: 47,167,444,74
# MEMORIES
# Bounding box: 50,269,691,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 50,341,1256,52
# SCENE: BH FORGOTTEN SETTLEMENT MEMORI
# Bounding box: 82,566,148,43
# ESKER
# Bounding box: 347,592,288,39
# Do you hear music?
# Bounding box: 344,761,467,40
# Aren't you forgetting someone?
# Bounding box: 347,945,871,39
# I can't wait to play with the whole group again. Can I start?
# Bounding box: 451,1040,55,26
# Yes.
# Bounding box: 454,1089,110,36
# Not yet.
# Bounding box: 345,1269,684,40
# Oh, ok. I'll— I'll get to play soon though, right?
# Bounding box: 451,1490,56,26
# Yes.
# Bounding box: 345,1696,373,39
# Ok, I won't let you down!
# Bounding box: 1387,345,34,46
# 2
# Bounding box: 345,1939,1149,39
# Wow... How long has it been since I got to make music with everyone around a
# Bounding box: 344,1977,148,39
# campfire?
# Bounding box: 347,2211,444,40
# I'm really happy we're all here.
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_22.jpg
# i --> 20
# waiting for 63 seconds...
# getting ocr for local image --> OW_Script_v3_pt2_Page_23.jpg
# Bounding box: 49,55,783,75
# GRAVITY CANNON
# Bounding box: 50,168,723,75
# SOLANUM'S SHIP
# Bounding box: 51,271,691,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 51,343,893,53
# SCENE: Bi-l GRAVITY CANNON 2
# Bounding box: 39,591,217,45
# GABBRO
# Bounding box: 346,606,910,40
# Hey, time pal. So you're getting the band back together, huh?
# Bounding box: 344,776,1089,40
# Go on, go find the others. I'll be here. You don't need me yet, but you will.
# Bounding box: 344,949,835,50
# What do you say, time buddy? Ready to start the 64usic?
# Bounding box: 450,1055,56,26
# Yes.
# Bounding box: 453,1104,110,36
# Not yet.
# Bounding box: 346,1284,488,40
# No rush, I'm not going anywhere.
# Bounding box: 450,1505,56,26
# Yes.
# Bounding box: 346,1710,361,36
# Heh, this should be cool.
# Bounding box: 346,1954,1268,39
# I tell you what, this has been really fun. And I got to help make something pretty cool,
# Bounding box: 344,1992,370,39
# so I've got no complaints.
# Bounding box: 346,2146,620,40
# I mean, not me, exactly, but close enough.
# Bounding box: 346,2288,1277,39
# It's the kind of thing that makes you glad you stopped and smelled the pine trees along
# Bounding box: 344,2326,288,39
# the way, you know?
# ------------------------------------------------------------
# getting ocr for local image --> OW_Script_v3_pt2_Page_24.jpg
# Bounding box: 69,55,634,75
# HANGING CITY
# Bounding box: 69,168,471,75
# EYE SHRINE
# Bounding box: 68,271,692,49
# PLANET: BRITTLE HOLLOW
# Bounding box: 68,343,678,52
# SCENE: BH EYE SHRINE I
# Bounding box: 53,593,198,44
# RIEBECK
# Bounding box: 365,579,1144,40
# I'm pretty sure we'll need the others for this next part. We'll need, you know...
# Bounding box: 363,628,139,29
# everyone.
# Bounding box: 345,733,616,39
# No rush! Take your time. It mightnotevenexisthere„.
# Bounding box: 343,958,230,39
# Should I begin?
# Bounding box: 449,1053,55,26
# Yes.
# Bounding box: 452,1102,110,36
# Not yet.
# Bounding box: 343,1282,447,40
# Ok, I'll wait until you're ready.
# Bounding box: 449,1503,55,26
# Yes.
# Bounding box: 341,1707,412,40
# You g-got it. I'll do my best!
# Bounding box: 345,1969,589,40
# I learned a lot, by the end of everything.
# Bounding box: 342,2125,1141,39
# The past is past, now, but that's... you know, that's okay! It's never really gone
# Bounding box: 343,2162,1166,40
# completely. The future is always built on the past, even if we won't get to see it.
# Bounding box: 343,2303,643,40
# Still, it's, um, time for something new, now.
# ------------------------------------------------------------

# %% [markdown]
# ________________________
#
# ## Look at combined ocr_dfs for local screenshots
#
# - Text extracted for 24 images:

# %%
pd.concat(dfs)
# Out:
#   language  text_angle orientation  \
# 0       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
# 3       en         0.0          Up
# 4       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
# 0       en         0.0          Up
# 1       en         0.0          Up
# 2       en         0.0          Up
#
#                                              regions model_version  \
# 0  {'bounding_box': '50,55,1569,2326', 'lines': [...    2021-04-01
# 0  {'bounding_box': '43,55,1545,1261', 'lines': [...    2021-04-01
# 0  {'bounding_box': '32,55,1574,2336', 'lines': [...    2021-04-01
# 0  {'bounding_box': '58,55,741,280', 'lines': [{'...    2021-04-01
# 1  {'bounding_box': '35,486,156,44', 'lines': [{'...    2021-04-01
# 2  {'bounding_box':
# 1  OW_Script_v3_pt2_Page_10
# 2  OW_Script_v3_pt2_Page_10
# 0  OW_Script_v3_pt2_Page_11
# 1  OW_Script_v3_pt2_Page_11
# 2  OW_Script_v3_pt2_Page_11
# 0  OW_Script_v3_pt2_Page_12
# 0  OW_Script_v3_pt2_Page_13
# 1  OW_Script_v3_pt2_Page_13
# 2  OW_Script_v3_pt2_Page_13
# 0  OW_Script_v3_pt2_Page_14
# 0  OW_Script_v3_pt2_Page_15
# 0  OW_Script_v3_pt2_Page_16
# 1  OW_Script_v3_pt2_Page_16
# 2  OW_Script_v3_pt2_Page_16
# 0  OW_Script_v3_pt2_Page_17
# 0  OW_Script_v3_pt2_Page_18
# 0  OW_Script_v3_pt2_Page_19
# 0  OW_Script_v3_pt2_Page_20
# 1  OW_Script_v3_pt2_Page_20
# 2  OW_Script_v3_pt2_Page_20
# 0  OW_Script_v3_pt2_Page_21
# 1  OW_Script_v3_pt2_Page_21
# 2  OW_Script_v3_pt2_Page_21
# 0  OW_Script_v3_pt2_Page_23
# 1  OW_Script_v3_pt2_Page_23
# 2  OW_Script_v3_pt2_Page_23
# 0  OW_Script_v3_pt2_Page_24
# 1  OW_Script_v3_pt2_Page_24
# 2  OW_Script_v3_pt2_Page_24

# %%
out_df = pd.concat(dfs)
out_df.reset_index(drop=True,inplace=True)
out_df.to_json('screenshot_ocr.json')

# %% [markdown]
# ## *UPDATE -->> I exported the results to json, so not going to run again...*
# - The above cell for OCR w/ rate limiting takes around 33 minutes to complete

# %%
out_df
# Out:
#    language  text_angle orientation  \
# 0        en         0.0          Up
# 1        en         0.0          Up
# 2        en         0.0          Up
# 3        en         0.0          Up
# 4        en         0.0          Up
# 5        en         0.0          Up
# 6        en         0.0          Up
# 7        en         0.0          Up
# 8        en         0.0          Up
# 9        en         0.0          Up
# 10       en         0.0          Up
# 11       en         0.0          Up
# 12       en         0.0          Up
# 13       en         0.0          Up
# 14       en         0.0          Up
# 15       en         0.0          Up
# 16       en         0.0          Up
# 17       en         0.0          Up
# 18       en         0.0          Up
# 19       en         0.0          Up
# 20       en         0.0          Up
# 21       en         0.0          Up
# 22       en         0.0          Up
# 23       en         0.0          Up
# 24       en         0.0          Up
# 25       en         0.0          Up
# 26       en         0.0          Up
# 27       en         0.0          Up
# 28       en         0.0          Up
# 29       en         0.0          Up
# 30       en         0.0          Up
# 31       en         0.0          Up
# 32       en         0.0          Up
# 33       en         0.0          Up
# 34       en         0.0          Up
# 35       en         0.0          Up
# 36       en         0.0          Up
# 37       en         0.0          Up
# 38       en         0.0          Up
# 39       en         0.0          Up
# 40       en         0.0          Up
# 41       en         0.0          Up
# 42       en         0.0          Up
# 43       en         0.0          Up
#
#                                               regions model_version  \
# 0   {'bounding_box': '50,55,1569,2326', 'lines': [...    2021-04-01
# 1   {'bounding_box': '43,55,1545,1261', 'lines': [...    2021-04-01
# 2   {'bounding_box': '32,55,1574,2336', 'lines': [...    2021-04-01
# 3   {'bounding_box': '58,55,741,280', 'lines': [{'...    2021-04-01
# 1   OW_Script_v3_pt2_Page_03
# 2   OW_Script_v3_pt2_Page_04
# 3   OW_Script_v3_pt2_Page_05
# 4   OW_Script_v3_pt2_Page_05
# 5   OW_Script_v3_pt2_Page_05
# 6   OW_Script_v3_pt2_Page_05
# 7   OW_Script_v3_pt2_Page_05
# 8   OW_Script_v3_pt2_Page_06
# 9   OW_Script_v3_pt2_Page_07
# 10  OW_Script_v3_pt2_Page_08
# 11  OW_Script_v3_pt2_Page_09
# 12  OW_Script_v3_pt2_Page_09
# 13  OW_Script_v3_pt2_Page_09
# 14  OW_Script_v3_pt2_Page_10
# 15  OW_Script_v3_pt2_Page_10
# 16  OW_Script_v3_pt2_Page_10
# 17  OW_Script_v3_pt2_Page_11
# 18  OW_Script_v3_pt2_Page_11
# 19  OW_Script_v3_pt2_Page_11
# 20  OW_Script_v3_pt2_Page_12
# 21  OW_Script_v3_pt2_Page_13
# 22  OW_Script_v3_pt2_Page_13
# 23  OW_Script_v3_pt2_Page_13
# 24  OW_Script_v3_pt2_Page_14
# 25  OW_Script_v3_pt2_Page_15
# 26  OW_Script_v3_pt2_Page_16
# 27  OW_Script_v3_pt2_Page_16
# 28  OW_Script_v3_pt2_Page_16
# 29  OW_Script_v3_pt2_Page_17
# 30  OW_Script_v3_pt2_Page_18
# 31  OW_Script_v3_pt2_Page_19
# 32  OW_Script_v3_pt2_Page_20
# 33  OW_Script_v3_pt2_Page_20
# 34  OW_Script_v3_pt2_Page_20
# 35  OW_Script_v3_pt2_Page_21
# 36  OW_Script_v3_pt2_Page_21
# 37  OW_Script_v3_pt2_Page_21
# 38  OW_Script_v3_pt2_Page_23
# 39  OW_Script_v3_pt2_Page_23
# 40  OW_Script_v3_pt2_Page_23
# 41  OW_Script_v3_pt2_Page_24
# 42  OW_Script_v3_pt2_Page_24
# 43  OW_Script_v3_pt2_Page_24

# %% [markdown]
# __________
#
# ## Nested OCR text words as `txt` column

# %%
def ocr_expand(x):
        
    txt = []
    
    for line in x.regions['lines']:
        for word in line['words']:
            txt.append(word['text'])
            
    return txt

# %%
out_df['txt'] = out_df.apply(lambda x: ocr_expand(x), axis=1)

# %%
final_df = out_df

# %%
final_df.txt
# Out:
# 0     [ESKER, -, LUNAR, OUTPOST, PLANET:, ATTLEROCK,...
# 1     [ESKER, -, LUNAR, OUTPOST, PLANET:, ATTLEROCK,...
# 2     [ESKER, -, LUNAR, OUTPOST, PLANET:, ATTLEROCK,...
# 3     [EYE, LOCATOR, PLANET:, ATTLEROCK, SCENE:, AR,...
# 4                                               [CHERT]
# 5     [Goodness,, it's, you!, Hello!, I, take, it, y...
# 6                             [then?, Welcome, to, the]
# 7     [Hornfels, asked, me, to, update, our, star, c...
# 8     [EYE, LOCATOR, SCROLL, PLANET:, ATTLEROCK, SCE...
# 9     [RIEBECK, -, ATTLEROCK, NOTES, PLANET:, ATTLER...
# 10    [CHERT, -, ATTLEROCK, NOTES, PLANET:, ATTLEROC...
# 11    [ESKER, SIGNALSCOPE, LOG, PLANET:, ATTLEROCK, ...
# 12                                              [CHERT]
# 13    [Hm?, Oh,, it's, you!, I, take, it, your, firs...
# 14    [BLACK, HOLE, FORGE, PLANET:, BRITTLE, HOLLOW,...
# 15                                              [CHERT]
# 16    [I, found, Nomai, writing, about, the, Sun, St...
# 17    [BLACK, HOLE, FORGE, SCROLL, PLANET:, BRITTLE,...
# 18                                              [CHERT]
# 19    [The, stars!, They're, all, dying!, There've, ...
# 20    [BLACK, HOLE, FORGE, ALIGN, PLANET:, BRITTLE, ...
# 21    [FORGE, ASH, TABLET, Oh,, hello..., PLANET:, B...
# 22                                              [CHERT]
# 23    [Does, it, help?, A, time, loop,, you, said?, ...
# 24    [FORGOTTEN, SETTLEMENT, MIGRATION, PLANET:, BR...
# 25    [ESCAPE, POD, I, PLANET:, BRITTLE, HOLLOW, SCE...
# 26    [ESCAPE, POD, WARNING, PLANET:, BRITTLE, HOLLO...
# 27                                             [GABBRO]
# 28    [Okay,, here's, a, weird, one, for, you, —, I,...
# 29    [FORGOTTEN, SETTLEMENT, ENTRANCE, PLANET:, BRI...
# 30    [FORGOTTEN, SETTLEMENT, EYE, SHRINE, PLANET:, ...
# 31    [FORGOTTEN, SETTLEMENT, VESSEL, MURALS, PLANET...
# 32    [FORGOTTEN, SETTLEMENT, ILEX, POEM, PLANET:, B...
# 33                                              [CHERT]
# 34    [The, stars, were, beautiful,, weren't, they?,...
# 35    [FORGOTTEN, SETTLEMENT, MEMORIES, PLANET:, BRI...
# 36                                                  [2]
# 37    [Wow..., How, long, has, it, been, since, I, g...
# 38    [GRAVITY, CANNON, SOLANUM'S, SHIP, PLANET:, BR...
# 39                                             [GABBRO]
# 40    [Hey,, time, pal., So, you're, getting, the, b...
# 41    [HANGING, CITY, EYE, SHRINE, PLANET:, BRITTLE,...
# 42                                            [RIEBECK]
# 43    [I'm, pretty, sure, we'll, need, the, others, ...
# Name: txt, dtype: object

# %% [markdown]
# ### Export the dataframe w/ extracted text to JSON

# %%
final_df.to_json('screenshot_ocr_w_text.json')

# %% [markdown]
# ### To view full text, we join the ocr text for further analysis...

# %%
' '.join(out_df.txt.iloc[0])
# Out:
# "ESKER - LUNAR OUTPOST PLANET: ATTLEROCK SCENE: AR ESKAR I FELDSPAR Whoa! Where'd you come from? No one's come here in... well, ever, actually. That makes you the second Hearthian to ever reach Dark Bramble — after me, of course. Well done! ...Say, it's you! They made you an astronaut? And you haven't blown yourself up yet, good for you! Feldspar! You're alive! We all thought you were dead for sure. Have you been here in Dark Bramble all this time? ...You never were the brightest hatchling, were you. Yeah, that's right, I'm alive. Been camping out here since my ship, uh, y'know. Crashed. Violently. Wait, what? You crashed? But you're the greatest pilot in Hearthian history! Oh, this is a good story. I'd just finished exploring the core of Giant's Dee and needed a new challenge, and none of us had ever been inside Dark Bramble, so I tkink, hey, let's give that a try. I've been cruising around for a while, dodging the odd massive, interdimensional vine bristling with thorns, when I run into this huge anglerfish, the biggest I've ever seen. I pull a few stunts, try to shake the thing off — nothing too fancy. I'm going full-speed when the fish clips me, knocks me into a vine, and... ...well, like I said, I crash. Blammo! On impact, my ship starts making noises like it's coming apart from the inside, and I think, well, that ain't great. Sure enough, I barely get out of there before the electrical systems start sparking like crazy. It's either move fast or die unpleasantly, so I had to put a little distance between me and my poor, fried ship. I camped out near where I crashed at first. I found this skeleton later — great find, woul&ve been stupid not to use it."

